# %%
import pandas as pd

group_schema = {
    "Economic": {"Area": [""],
                 "Structure": ["building", "installation", "infrastructure", "facility", "tower", \
                              "school", "university", \
                              "airport", "subway", "farm", "charity", "skyscraper", \
                              ],
                 "Capability": ["knowledge", "intelligence", "wisdom", "information", "capital", \
                                "economy", "currency", "bank", "business", "asset", "fund", "shop", \
                                "finance", "innovation", "job", "budget", "spending", "paycheck", "market", \
                                "investment", "factory", "welfare", "pension", "accounting", "industry", "agriculture", \
                                "income", "expensive", "wealth", "economical", "booty", "trading", \
                                "profit", "resource", "price", "monie", "gambling", "advertising", "tool", "cargo","reconstruction", \
                                "contract", "tax", "financial", "wealth", "power", "prosperity", "excise", \
                                "enterprise", "expenditure", "deal", "property", "money", "oil", "water", "energy", "currency", "jewel", \
                                "jewellery", "gold", "industry", "agriculture", "inflation", "debt", "income"],
                 "Organisation": ["agency", "corporation", "rich"],
                 "Person": ["passenger", "customer", "competitor", "associate", "collaborator", \
                           "student", "graduate", "scholar", "teacher", "dr", "professor", "intellectual", \
                            "analyst", "merchant", "employee", "economist", "worker", "entrepreneur", "shopkeeper", "servant", \
                            "company", "shareholder", "contractor", "consumer", \
                            "ceo", "director", "manager"],
                 "Event": ["recession", "export", "import", "spending", "purchase", "buy", "sell", "trade", "work", "training", "education", \
                          "lecture", "sponsor", "growth", "retirement", "gamble", "production", "livelihood", "bankruptcy"]},
    "Food":     {"Area": [""],
                "Structure": ["farm"],
                "Capability": ["food"],
                "Organisation": [""],
                "Person": ["farmer"],
                "Event": [""]},
    "Health" : {"Area": [""],
                "Structure": ["hospital", 
                              "tomb"],
                "Capability": ["heart", "soul", "skin graft", "palm", "limb", "blood", "body", "organ", "intestine", "tongue", \
                               "medicine", "remedy", "drug", "chemical", "vaccine", "health", \
                               "vermin", "parasite", "AIDS"],
                "Organisation": ["disabled"],
                "Person": ["doctor", "nurse", \
                           "blood donor", \
                           "injured"], \
                "Event": [""]},
    "Environment": {"Area": ["planet", "world", "place", "ground", "land", "sea", "site", "north", "south", "east", "west", "jungle", "desert"],
                    "Structure": ["street"],
                    "Capability": [""],
                    "Organisation": [""],
                    "Person": [""],
                    "Event": [""]},
    "Personal" : {"Area": ["sanctuary", "shelter", "refuge", \
                          "underworld"],
                "Structure": ["safe haven", "road", "house", "home"],
                "Capability": ["goal", "cause", "action", "commitment", "effort", "awakening", \
                               "philosophy", "belief", \
                               "heroin", \
                               "intoxicant", "sarin", "nerve agent", "nerve gas", "anthrax"],
                "Organisation": ["humans", "humanity", "humankind", "mankind", "personnel", "individuals", "people", "group", \
                                 "adults", "men", "gentlemen", "women", "ladies", "children", "boys", "girls", "youths", \
                                 "family", "bretheren", "parents", "husbands", "fathers", "dads", "wives", "mums", "mothers", "spouses", \
                                 "daughters", "sons", "sisters", "brothers", \
                                 "relatives", "nieces", "nephews", \
                                 "forefathers", "grandparents", "grandfathers", "granddads", "grandmothers", "nannas", "grandsons", "granddaughters", \
                                 "brotherhood", "brethern", \
                                 "strangers", "friends", "allies", "partners", "predecessors", "successors", "volunteers", \
                                 "leaders", "leadership", "heroes", \
                                 "law enforcement", "law-enforcement", \
                                 "mafia"],
                "Person": ["human", "humanity", "person", "individual", \
                           "adult", "man", "gentleman", "woman", "lady", "child", "boy", "girl", "youth", \
                           "parent", "husband", "father", "dad", "wife", "mum", "mother", "spouse", \
                           "daughter", "son", "sister", "brother", \
                           "relative", "niece", "nephew", \
                           "forefather", "grandparent", "grandfather", "granddad", "grandmother", "nanna", "grandson", "granddaughter", \
                           "stranger", "friend", "ally", "partner", "", "companion", "predecessor", "successor", "volunteer", "fellow", \
                           "leaders", "leadership", "heroes", \
                           "imbecile", "critic", "hypocrite", "fool", \
                           "police", "officer", "policeman", "firefighter", "rescuer", \
                           "protector", "guardian", "captive", "marshal", "innocent", "guard", \
                           "victim", "dead", "casualty", "persecuted", "slave", \
                           "wolf", "snake", "dog", \
                           "criminal", "prisoner", "murderer", "terrorist", "hijacker", "outlaw", "violator", "killer", "executioner", "thief"],
                "Event": ["confiscation", "arrest", "investigation", "enforcement", "prohibition", "shielding", "punishment", "imprisonment", "jailing"]},
    
    "Community": {"Area": ["heaven", "paradise"],
                 "Structure": ["camp", \
                              "mosque", "sanctity", "cathedral"],
                 "Capability": ["creed", "ideology", \
                                "atheism", \
                                "poetry", "song", "picture", "art", "poem", "entertainment", "symbol", "banner", \
                                "liberty", "sovereignty", "pluralism", "patriotism", "democracy", "communism", "bipartisanship", \
                                "nationalism", "fascism", "nazism", "totalitarianism", "nazi", "tyranny", "sectarianism", "anti-semitism", "anti-semitism", \
                                "faith", "pray", "prayer", "mourn", "vigil", "prayer", "remembrance", "praise", "bless", "last rites", "angel", \
                                "memorial", "revelation", "sanctify", "grace", "religion", "repentance", "exalted", "repent", "seerah", "confession", \
                                "exaltation", "praise", "commandment", "wonderment", "supplication", "worship", "testament", "blessing", "ascension", \
                                "da'ees", "piety", "creationism", "monotheism", "sheerah"],
                 "Organisation": ["population", "community", "neighborhood", "tribe", \
                                  "caliph", "ummah", "ulamah", "ulema", "polytheist", "houries", \
                                  "cult"],
                 "Person": ["neighbour", "religionist", \
                            "Apostle", "Prophet", "apostle", "prophet", "lord", "priest", "all-mighty", \
                            "cleric", "immam", "saint", "st.", "sheikh", "shaykh", "preacher", \
                            "kufr", "kuffaar", "infidel", "evildoer", "mushrik", "unbeliever", "disbeliever", "mushrikeen", "pagan", \
                            "idolater", "apostate", "heretic", "atheist"],
                 "Event": [""]},
    
    "Political": {"Area": ["homeland", "statelet", "territory", "peninsula", "city", "country", "region", \
                           "area", "peninsula", "continent", \
                           "battlefield", "beachead", "training camp"],
                  "Structure": ["embassy", \
                               "prison", "sanctuary", "court", "jail", \
                               "fortress", "fortification"],
                  "Capability": ["struggle", "jihad", "confrontation", "feud", "partisanship", "division", "dissociation", "boycott", "rivalry", "crisis", \
                                 "media", \
                                 "human right", "unity", "citizenship", 
                                 "power", "edict", "legislation", "policy", "diplomacy", \
                                 "petition", "memorandum", \
                                 "humanitarian aid", \
                                 "security", "law", "decree", "sailor", "warrant", \
                                 "penalty", "statute", "attorney", "treaty", "duty", "justification", \
                                 "judge", "custody", "justice", "denunciation", "agreement", \
                                 "duty", "morality", "innocence", "legitimacy", \
                                 "chain of command", "force", "uniform", "target", "materiel", \
                                 "battleship", "aircraft carriers", "tank", "air power", \
                                 "weapon", "weaponry", "bomb", "missile", "munition", "explosive", "arms", "bullet", "sword", "spear", "gun", "rocket"],
                  "Organisation": ["public", "society", "citizens", "nation", "union", "civilization", "patriot", "empire", \
                                   "state", "compatriot", "superpower", "kingdom", \
                                   "ministry", "government", "congress", "alliance", "diplomats", "delegates", \
                                   "coalition", "axis", "compatriots", "administration", "political party", "senate", "institution", \
                                   "opposition", \
                                   "politicians", \
                                   "nomad", \
                                   "journalist", \
                                   "movement", "minority", "emigrant", "oppressed", "persecuted", \
                                   "monarchy", "communist", "refugees", "migrants", \
                                   "Regime", "regime", "opponent", "dictatorship", \
                                   "military", "mujahideen", "army", "navy", "air force", "troops", "special forces", "vanguard", "mujahidin", \
                                   "infantry", "cavalry"],
                  "Person": ["countryman", "freeman", "advocate", \
                             "president", "minister", "speaker", "prime minister", "senator", "mayor", "governor", \
                             "king", "queen", "prince", "princess", "commander-in-chief", "ruler", "chairman", \
                             "congressman", "amir", "pharaoh", "dignitary", "reformer", \
                             "lawyer", "agent", "authority", \
                             "commander", "vetran", "invader", \
                             "defender", "recruit", "guerrilla", "knight", "fatality", "martyr",  \
                             "aggressor", "troop", "fighter", "soldier", "warrior", "mujahid", "soldier", "airman", "marine", \
                             "traitor", "oppressor", "enemy", "crusader", "occupier", "shooter"],
                  "Event": ["election", "reign", "trial", "surveillance", "imprisonment", "victory", \
                           "defeat", "aggression", "invasion", "occupation", "revolution", "oppression", \
                           "conquest", "surrender", "victory", "war", "warfare", "battle", "blockade", \
                           "genocide", "brutalize", "holocaust", "torture", "slaughter", "bloodshed"]},
}

index = [list(cat.keys()) for cat in list(group_schema.values())][0]
themes = [theme for theme in group_schema.keys()]
display(pd.DataFrame([["" for theme in themes] for idx in index], index = index, columns = themes))
# Out:
#              Economic Food Health Environment Personal Community Political
# Area
# Structure
# Capability
# Organisation
# Person
# Event

# %%
import spacy
import pandas as pd
from spacy.tokenizer import Tokenizer
from spacy.util import compile_infix_regex
from spacy.lang.char_classes import CONCAT_QUOTES, LIST_ELLIPSES, LIST_ICONS
from spacy.lang.char_classes import ALPHA, ALPHA_LOWER, ALPHA_UPPER

nlp = spacy.load("en_core_web_sm")

def custom_tokenizer(nlp):
    inf = list(nlp.Defaults.infixes)
    inf = [x for x in inf if
           '-|–|—|--|---|——|~' not in x]  # remove the hyphen-between-letters pattern from infix patterns
    infix_re = compile_infix_regex(tuple(inf))

    infixes = (
            LIST_ELLIPSES
            + LIST_ICONS
            + [
                r'(?<=[0-9])[+\\-\\*^](?=[0-9-])',
                r'(?<=[{al}{q}])\\.(?=[{au}{q}])'.format(
                    al=ALPHA_LOWER, au=ALPHA_UPPER, q=CONCAT_QUOTES
                ),
                # REMOVE: commented out regex that splits on hyphens between letters:
                # r"(?<=[{a}])(?:{h})(?=[{a}])".format(a=ALPHA, h=HYPHENS),
                # EDIT: remove split on slash between letters, and add comma
                # r'(?<=[{a}0-9])[:<>=/](?=[{a}])'.format(a=ALPHA),
                r'(?<=[{a}0-9])[:<>=,](?=[{a}])'.format(a=ALPHA),
                # ADD: ampersand as an infix character except for dual upper FOO&FOO variant
                r'(?<=[{a}0-9])[&](?=[{al}0-9])'.format(a=ALPHA, al=ALPHA_LOWER),
                r'(?<=[{al}0-9])[&](?=[{a}0-9])'.format(a=ALPHA, al=ALPHA_LOWER),
            ]
    )

    infix_re = spacy.util.compile_infix_regex(infixes)

    return Tokenizer(nlp.vocab, prefix_search=nlp.tokenizer.prefix_search,
                     suffix_search=nlp.tokenizer.suffix_search,
                     infix_finditer=infix_re.finditer,
                     token_match=nlp.tokenizer.token_match,
                     rules=nlp.Defaults.tokenizer_exceptions)

nlp.tokenizer = custom_tokenizer(nlp)

text = "Trilateral Research is a UK and IE-based enterprise, founded in 2004. Our rigorous research is at the foundation of our work. \
We provide regulatory and policy advice; develop new data-driven technologies and contribute to the latest standards in safeguarding privacy, ethics and human rights within the public and private sector. \
Our teams collaborate across the technology-social disciplinary divide, being able to assess the impact of emerging technologies to avoid adverse and unwanted consequences while delivering sustainable innovation. \
We focus our efforts on areas where the application of our research can make a difference in enhancing societal wellbeing. \
Find out about our people and our culture, and see how our mission drives the projects we take on, the key data protection services we provide, and the products and supplementary services we develop. \
Trilateral is committed to the UN Global Compact corporate responsibility initiative and its principles in the areas of human rights, labour, the environment and anti-corruption."

doc = nlp(text)

def get_span(doc, token):
    """
    function to get the compound span of a token
    """
    
    for left in token.subtree:
        if left.i == token.i:
            return doc[token.i : token.i + 1]
        if left.dep_ in ["compound", "nmod", "amod", "appos", "acl", "relcl"]:
            return doc[left.i : token.i + 1]
        
pd.set_option("max_colwidth", None)
pd.set_option("max_rows", None)

display(pd.DataFrame([{
    "Token" : token,
    "Sentence": str(token.sent),
    "Named Entity": token.ent_type_ if token.ent_type else "",
    "Named Entity Explanation": spacy.explain(token.ent_type_).title() if token.ent_type else "",
    "Part of Speech": token.pos_,
    "Lemma": token.lemma_.title(),
    "Noun Phrase": str(get_span(doc, token)),
    "ASCOPE": "",
    "ASCOPE_type": "", 
    "HS Theme": "",
    "Comment": ""
} for token in doc if 
    token.pos_ in ["NOUN", "PROPN", "ADJ"] and 
    token.dep_ not in ["compound"]]))
# Out:
#                 Token  \
# 0            Research
# 1                  UK
# 2          enterprise
# 3            rigorous
# 4            research
# 5          foundation
# 6                work
# 7          regulatory
# 8              policy
# 9              advice
# 10                new
# 11        data-driven
# 12       technologies
# 13             latest
# 14          standards
# 15            privacy
# 16             ethics
# 17              human
# 18             rights
# 19             public
# 20            private
# 21             sector
# 22              teams
# 23  technology-social
# 24       disciplinary
# 25             divide
# 26               able
# 27             impact
# 28       technologies
# 29            adverse
# 30           unwanted
# 31       consequences
# 32        sustainable
# 33         innovation
# 34            efforts
# 35              areas
# 36        application
# 37           research
# 38         difference
# 39           societal
# ...
