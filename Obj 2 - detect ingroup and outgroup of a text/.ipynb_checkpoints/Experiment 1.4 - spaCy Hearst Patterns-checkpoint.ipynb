# %% [markdown]
# # spaCy Hearst Patterns
# ---
#
# In this experiment we test the utility of Hearst Patterns for detecting the ingroup and outgroup of a text.
#
# For this experiment spaCy matcher is used with code adapted from: https://github.com/mmichelsonIF/hearst_patterns_python/blob/master/hearstPatterns/hearstPatterns.py
#
# Hypernym relations are semantic relationships between two concepts: C1 is a hypernym of C2 means that C1 categorizes C2 (e.g. “instrument” is a hypernym of “Piano”). For this research, the phrase, "America has enemies, such as Al Qaeda and the Taliban" would return the following '[('Al Qaeda', 'enemy'), ('the Taliban', 'enemy')]'. In this example, the categorising term 'enemy' is a hypernym of both 'Al Qaeda' and the 'Taliban'; conversely 'al Qaeda' and 'the Tabliban' are hyponyms of 'enemy'. Using this technique, hypernym terms could be classified as ingroup or outgroup and named entities identified as hyponym terms could be identified as either group.

# %% [markdown]
# # Notes for next time
#
# re-add removal of "DET" stop words
#
# add "DET" to patterns
#
# add is_hypernym and has_hyponyms to token
#
# add is_hyponym and has hypernym to token
#
# review test data for ingroups and outgroups with displacy
#
# begin to look at how to create dependency rules, probably only possible with Dependency Matcher

# %% [markdown]
# ## Setup the spaCy Pipeline

# %%
# %%time
import importlib
import pipeline
importlib.reload(pipeline)

cnd = pipeline.CND(merge = True)

print(cnd.nlp.meta['name'])
print([pipe for pipe in cnd.nlp.pipe_names])
# Out:
# core_web_md
# ['tagger', 'parser', 'ner', 'Named Entity Matcher', 'merge_entities', 'Concept Matcher', 'merge_custom_chunks', 'hearst pattern matcher']
# Wall time: 19.6 s

# %% [markdown]
# ## Create Dataset of Political Speeches from George Bush, Osama bin Laden and Martin Luther King

# %%
# %%time
import os
import importlib
import cndobjects
importlib.reload(cndobjects)

dirpath = r'C:\Users\Steve\OneDrive - University of Southampton\CNDPipeline\dataset'

orators = cndobjects.Dataset(cnd, dirpath)
# Out:
# parsing:  bush (2001-09-11) 911 Address to the Nation
# parsing:  bush (2001-09-14) Remarks at the National Day of Prayer & Remembrance Service
# parsing:  bush (2001-09-15) First Radio Address following 911
# parsing:  bush (2001-09-17) Address at Islamic Center of Washington, D.C.
# parsing:  bush (2001-09-20) Address to Joint Session of Congress Following 911 Attacks
# parsing:  bush (2001-10-07) Operation Enduring Freedom in Afghanistan Address to the Nation
# parsing:  bush (2001-10-11) 911 Pentagon Remembrance Address
# parsing:  bush (2001-10-11) Prime Time News Conference on War on Terror
# parsing:  bush (2001-10-11) Prime Time News Conference Q&A
# parsing:  bush (2001-10-26) Address on Signing the USA Patriot Act of 2001
# parsing:  bush (2001-11-10) First Address to the United Nations General Assembly
# parsing:  bush (2001-12-11) Address to Citadel Cadets
# parsing:  bush (2001-12-11) The World Will Always Remember 911
# parsing:  bush (2002-01-29) First (Official) Presidential State of the Union Address
# parsing:  king (1963-04-03) Ive Been to the Mountaintop
# parsing:  king (1963-08-28) I Have a Dream
# parsing:  king (1965-03-25) Our God is Marching On
# parsing:  king (1967-04-04) Beyond Vietnam
# parsing:  king (1967-04-14) The Other America
# parsing:  laden (1996-08-23) Declaration of Jihad Against the Americans Occupying the Land of the Two Holiest Sites
# parsing:  laden (2001-01-07) Osama Bin Laden Letter Calling For Global Islamic State
# parsing:  laden (2001-10-07) Al-Jazirah Carries Bin Ladin's Address on US Strikes
# parsing:  laden (2001-11-09) Bin Laden's Statement The Sword Fell
# parsing:  laden (2002-11-24) OBL Letter to America
# parsing:  laden (2004-11-01) Al Jazeera Speech
# Wall time: 19.8 s

# %%
doc = orators["bush"][4].doc

n = 30

for ent in doc._.custom_chunks:
    
    if ent._.ATTRIBUTE == "outgroup":# or ent._.ATTRIBUTE == "ingroup":
        print(str(ent.sent).strip())
        print(str(ent).ljust(n), '=>', ent.root.ent_type_, '=>', ent._.ATTRIBUTE, '=>', [t.tag_ for t in ent])
        print()
        
#         #if ent.root._.has_hypernym._.ATTRIBUTE == "outgroup" or 
#             print(str(ent.sent).strip())
#             print(str(ent).ljust(n), '=>', ent.root._.has_hypernym._.ATTRIBUTE.ljust(n), '=>', str(ent.root._.has_hypernym).ljust(n), '=>')
#             print('---')
#     #         print(str(ent).ljust(n), '=>', str(ent.root._.is_hyponym).ljust(n), '=>', ent._.ATTRIBUTE.ljust(n), '=>', ent._.span_type.ljust(n))
# Out:
# We have seen it in the courage of passengers, who rushed terrorists to save others on the ground -- passengers like an exceptional man named Todd Beamer.
# terrorists                     =>  => outgroup => ['NNS']
#
# Whether we bring our enemies to justice, or bring justice to our enemies, justice will be done.
# enemies                        =>  => outgroup => ['NNS']
#
# Whether we bring our enemies to justice, or bring justice to our enemies, justice will be done.
# enemies                        =>  => outgroup => ['NNS']
#
# On September the 11th, enemies of freedom committed an act of war against our country.
# enemies of freedom             =>  => outgroup => ['NNS']
#
# The evidence we have gathered all points to a collection of loosely affiliated terrorist organizations known as al Qaeda.
# collection of loosely affiliated terrorist organizations =>  => outgroup => ['NN']
#
# They are some of the murderers indicted for bombing American embassies in Tanzania and Kenya, and responsible for bombing the USS Cole.
# murderers                      =>  => outgroup => ['NNS']
#
# Al Qaeda is to terror what the mafia is to crime.
# mafia                          => ORG => outgroup => ['NN']
#
# The terrorists practice a fringe form of Islamic extremism that has been rejected by Muslim scholars and the vast majority of Muslim clerics, a fringe movement that perverts the peaceful teachings of Islam.
# terrorists                     =>  => outgroup => ['NNS']
#
# The terrorists' directive commands them to kill Christians and Jews, to kill all Americans, and make no distinctions among military and civilians, including women and children.
# terrorists' directive          =>  => outgroup => ['NN']
#
# There are thousands of these terrorists in more than 60 countries.
# thousands of these terrorists  => CARDINAL => outgroup => ['NNS']
#
# The leadership of al Qaeda has great influence in Afghanistan and supports the Taliban regime in controlling most of that country.
# Taliban regime                 =>  => outgroup => ['NN']
#
# After all, we are currently its largest source of humanitarian aid; but we condemn the Taliban regime.
# Taliban regime                 =>  => outgroup => ['NN']
#
# It is not only repressing its own people, it is threatening people everywhere by sponsoring and sheltering and supplying terrorists.
# terrorists                     =>  => outgroup => ['NNS']
#
# By aiding and abetting murder, the Taliban regime is committing murder.
# Taliban regime                 =>  => outgroup => ['NN']
#
# Close immediately and permanently every terrorist training camp in Afghanistan, and hand over every terrorist, and every person in their support structure, to appropriate authorities.
# terrorist                      =>  => outgroup => ['NN']
#
# They will hand over the terrorists, or they will share in their fate.
# terrorists                     =>  => outgroup => ['NNS']
#
# The terrorists are traitors to their own faith, trying, in effect, to hijack Islam itself.
# terrorists                     =>  => outgroup => ['NNS']
#
# The terrorists are traitors to their own faith, trying, in effect, to hijack Islam itself.
# traitors                       =>  => outgroup => ['NNS']
#
# The enemy of America is not our many Muslim friends; it is not our many Arab friends.
# enemy of America               =>  => outgroup => ['NN']
#
# Our enemy is a radical network of terrorists, and every government that supports them.
# enemy                          =>  => outgroup => ['NN']
#
# These terrorists kill not merely to end lives, but to disrupt and end a way of life.
# terrorists                     =>  => outgroup => ['NNS']
#
# We will starve terrorists of funding, turn them one against another, drive them from place to place, until there is no refuge or no rest.
# terrorists of funding          =>  => outgroup => ['NNS']
#
# Either you are with us, or you are with the terrorists.
# terrorists                     =>  => outgroup => ['NNS']
#
# From this day forward, any nation that continues to harbor or support terrorism will be regarded by the United States as a hostile regime.
# hostile regime                 =>  => outgroup => ['NN']
#
# Terrorists attacked a symbol of American prosperity.
# Terrorists                     =>  => outgroup => ['NNS']
#
# We will come together to strengthen our intelligence capabilities to know the plans of terrorists before they act, and to find them before they strike.
# plans of terrorists            =>  => outgroup => ['NNS']

# %%
# %%time
from IPython.display import clear_output
import importlib
import pandas as pd
import hpspacy, hpregex
from tqdm import tqdm
importlib.reload(hpspacy)
importlib.reload(hpregex)


class hp_Analysis(object):
    
    """
    class function for analysing each Hearst Pattern Method of Text() objects from each
    Orator() in the Dataset() object.
    
    iterates over each Text() object within each Orator() of the Dataset() and returns
    the number of hyponym matches for each method.
    
    tested methods are:
    - regex patterns
    - spacy patterns (bronze): uses stopword list for noun chunking
    - spacy patterns (silver): uses modifier dependency for noun_chunking
    - spacy patterns (gold): uses stopword list compiled from pattern rule names
    
    input: Dataset Object
    outputs: 
    - quant: dataframe quantifying results, in the following format:
    
            | orator          | ... |
    regex   | hyponyms count  | ... |
    bronze  | hyponyms count  | ... |
    silver  | hyponyms count  | ... |
    gold    | hyponyms count  | ... |
    
    - hyponym_list: dict object of hyponym results for each orator and each method in the 
    following format:
    
    {"orator": {"method" : [hyponyms]}}
    """
    
    def __init__(self, dataset = None, orator_list = None, hyponym_list = None):
        
        if dataset is not None:
            self.quant = None # dataframe output quantifying hyponym results
        else:
            dataset = None
        
        self.methods = {"regex" : [], "spaCy" : []}
        
        #self.methods = {"regex" : [], "bronze" : [], "silver" : [], "gold" : []}
        
        # initialise the object when Dataset() is passed
        
        self.dataset = dataset # the dataset

        if orator_list is None:
            self.orator_list = [orator for orator in self.dataset if len(orator) > 0] # list of Orator() names containing Texts()
        else:
            orator_list = None

        if hyponym_list is None:
            self.hyponym_list = {orator.ref : {method : [] for method in self.methods} for orator in self.orator_list} # dict object containing hyponyms for each Orator()
        else:
            orator_list = None

        self.summarise(self.orator_list)

    def summarise(self, iterable):
        
        # initialise regex Hearst Pattern detection
        hr = hpregex.HearstPatterns(cnd.nlp, extended=True, merge = False)
        hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)
        
        #iterate over each orator in the dataset
        for orator in iterable:
            
            if orator.ref == "hitler":
                continue

            # temp dict for storing the results
            results_count = {key: 0 for key in self.methods.keys()}

            for text in tqdm(orator, desc = orator.ref):

                # get results for regex method
                try:
                    hyps = hr.find_hyponyms(str(text))

                    self.hyponym_list[orator.ref]["regex"].extend(hyps)

                    results_count["regex"] += len(hyps)
                except:
                    pass
#                     print("not analysed (regex):", text.reference)
                    
                try:
                    hyps = hs.find_hyponyms(str(text))
                    
                    self.hyponym_list[orator.ref]["spaCy"].extend(hyps)
                    
                    results_count["spaCy"] += len(hyps)
                    
                except:
                    print("not analysed(spacy):", text.reference)

                # get results for each of the spaCy methods
                
                
#                 for grade in list(self.methods.keys())[1:]:

#                     try:
#                         h = hpspacy.hearst_patterns(nlp, extended = True, predicatematch = grade)
#                         hyps = h.find_hyponyms(str(text))
#                         self.hyponym_list[orator.ref][grade].extend(hyps)
#                         results_count[grade] += len(hyps)
#                     except:
#                         print(f"not analysed {grade}: {orator.ref}")           

            for key, value in results_count.items():
                self.methods[key].append(value)
                
#         display(pd.DataFrame(not_analysed, columns = ["not analysed"]))
        self.quant = pd.DataFrame(self.methods, index = [orator.name.title() for orator in iterable])
        
output = None
output = hp_Analysis(dataset = {k : v for k, v in orators.items() if k.ref != "hitler"})
# Out:
# bush: 100%|██████████| 14/14 [00:14<00:00,  1.06s/it]
# king: 100%|██████████| 5/5 [00:11<00:00,  2.23s/it]
# laden: 100%|██████████| 6/6 [00:10<00:00,  1.79s/it]
# Wall time: 36.8 s

# %%
display(output.quant)
# Out:
#                     regex  spaCy
# George Bush            39     92
# Martin Luther King     22     53
# Osama Bin Laden        29     71

# %%
import importlib
import hpspacy
importlib.reload(hpspacy)

hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)
for pair in hs.find_hyponyms(orators["bush"][4].doc):
    print(str(pair[-1].sent).strip())
    print(pair)
    print(pair[0].root.is_hyponym, '=>', pair[0].root._.has_hypernyms)
    print("-"*5)
# Out:
# Tonight we are a country awakened to danger and called to defend freedom.
# (a country, 'be_a', we)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d4b6cebd5667> in <module>
#       7     print(str(pair[-1].sent).strip())
#       8     print(pair)
# ----> 9     print(pair[0].root.is_hyponym, '=>', pair[0].root._.has_hypernyms)
#      10     print("-"*5)
#
# AttributeError: 'spacy.tokens.token.Token' object has no attribute 'is_hyponym'

# %% [markdown]
# ## Create Hearst Pattern Detection Object

# %%
import importlib
import hpspacy
importlib.reload(hpspacy)

docs = ["There are works by such authors as Herrick, Goldsmith, and Shakespeare.",
        "There were bruises, lacerations, or other injuries were not prevalent.",
        "common law countries, including Canada, Australia, and England enjoy toast.",
        "Many countries, especially France, England and Spain also enjoy toast.",
        "There are such benefits as postharvest losses reduction, food increase and soil fertility improvement."
       ]
hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)

for doc in docs:
    print(hs.find_hyponyms(doc))
    print('----------')
# Out:
# []
# ----------
# []
# ----------
# [(common law countries, 'include', Canada), (common law countries, 'include', Australia), (common law countries, 'include', England)]
# ----------
# [(Many countries, 'especially', France), (Many countries, 'especially', England), (Many countries, 'especially', Spain)]
# ----------
# []
# ----------

# %% [markdown]
# ## Initial Test of Hearst Pattern Detection Object
#
# First sentence contains a 'first' relationship' where hypernym preceeds hyponym.
#
# Second sentence contains both a 'first' and 'last' relationship.

# %%
import importlib
import hpspacy
importlib.reload(hpspacy)

docs = [
    "We are hunting for terrorist groups, particularly the Taliban and al Qaeda",
    "We are hunting for the IRA, ISIS, al Qaeda and some other terrorist groups, especially the Taliban, Web Scientists and particularly Southampton University"
]

# hr = hpregex.HearstPatterns(cnd.nlp, extended=True, merge = False)
hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)
def show_hyps(o):
    
   
    for i, text in enumerate(o):
        print(i, "#####")
        print(hs.find_hyponyms(text))
    
        print('-----')

show_hyps(docs)
# Out:
# 0 #####
# [(Taliban, terrorist groups, 'particularly'), (al Qaeda, terrorist groups, 'particularly')]
# -----
# 1 #####
# [(Taliban, other terrorist groups, 'especially'), (Web Scientists, other terrorist groups, 'especially'), (Southampton University, other terrorist groups, 'especially')]
# -----

# %% [markdown]
# ## Test With a Larger Number of sentences

# %%
# %%time
import importlib
import hpspacy
importlib.reload(hpspacy)

# create a list of docs
docs = [
    "Forty-four percent of patients with uveitis had one or more identifiable signs or symptoms, such as red eye, ocular pain, visual acuity, or photophobia, in order of decreasing frequency.",
    "Other close friends, including Canada, Australia, Germany and France, have pledged forces as the operation unfolds.",
    "The evidence we have gathered all points to a collection of loosely affiliated terrorist organizations known as al Qaeda.",
    "Terrorist groups like al Qaeda depend upon the aid or indifference of governments.",
    "This new law that I sign today will allow surveillance of all communications used by terrorists, including e-mails, the Internet, and cell phones.",
    "From this day forward, any nation that continues to harbor or support terrorism will be regarded by the United States as a hostile regime.",
    "We are looking out for the Taliban, al Qaeda and other terrorist groups",
    "We are looking out for al Qaeda and other terrorist groups, especially the Taliban and the muppets"
]

for doc in docs:
    print(hs.find_hyponyms(doc))
# Out:
# [(red eye, symptoms, 'such_as'), (ocular pain, symptoms, 'such_as'), (visual acuity, symptoms, 'such_as'), (photophobia, symptoms, 'such_as')]
# [(Canada, Other close friends, 'include'), (Australia, Other close friends, 'include'), (Germany, Other close friends, 'include'), (France, Other close friends, 'include')]
# [(al Qaeda, collection of loosely affiliated terrorist organizations, 'know_as')]
# [(al Qaeda, Terrorist groups, 'like')]
# [(e-mails, terrorists, 'include'), (Internet, terrorists, 'include'), (cell phones, terrorists, 'include')]
# []
# []
# [(Taliban, other terrorist groups, 'especially'), (muppets, other terrorist groups, 'especially')]
# Wall time: 156 ms

# %% [markdown]
# ## Test with a Full Speech

# %%
import os
import json
import importlib
import hpspacy
importlib.reload(hpspacy)
from spacy import displacy


dirpath = os.getcwd()
file = "first_docs.json"
hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)

with open(os.path.join(dirpath, file), "r") as f:
    last_docs = json.load(f)

total = 0
for text in last_docs:
    doc = cnd(text[2])
    hyponyms = hs.find_hyponyms(doc)
    print(doc)
    print([t for t in doc])
    print(text[0], '=>', hyponyms)
    if not hyponyms: total += 1
    print('----------')
    
print(total, '/', len(last_docs))
# Out:
# we are looking for terrorist groups, such as the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, such, as, the, Taliban, ,, al Qeada, and, Southampton University]
# such_as => [(Taliban, terrorist groups, 'such_as'), (al Qeada, terrorist groups, 'such_as'), (Southampton University, terrorist groups, 'such_as')]
# ----------
# we are looking for terrorist groups, known as the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, known, as, the, Taliban, ,, al Qeada, and, Southampton University]
# known_as => [(Taliban, terrorist groups, 'know_as'), (al Qeada, terrorist groups, 'know_as'), (Southampton University, terrorist groups, 'know_as')]
# ----------
# we are looking for terrorist groups, including the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, including, the, Taliban, ,, al Qeada, and, Southampton University]
# including => [(Taliban, terrorist groups, 'include'), (al Qeada, terrorist groups, 'include'), (Southampton University, terrorist groups, 'include')]
# ----------
# we are looking for terrorist groups, especially the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, especially, the, Taliban, ,, al Qeada, and, Southampton University]
# especially => [(Taliban, terrorist groups, 'especially'), (al Qeada, terrorist groups, 'especially'), (Southampton University, terrorist groups, 'especially')]
# ----------
# we are looking for terrorist groups, like the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, like, the, Taliban, ,, al Qeada, and, Southampton University]
# like => [(Taliban, terrorist groups, 'like'), (al Qeada, terrorist groups, 'like'), (Southampton University, terrorist groups, 'like')]
# ----------
# we are looking for terrorist groups, mainly the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, mainly, the, Taliban, ,, al Qeada, and, Southampton University]
# mainly => [(Taliban, terrorist groups, 'mainly'), (al Qeada, terrorist groups, 'mainly'), (Southampton University, terrorist groups, 'mainly')]
# ----------
# we are looking for terrorist groups, mostly the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, mostly, the, Taliban, ,, al Qeada, and, Southampton University]
# mostly => [(Taliban, terrorist groups, 'mostly'), (al Qeada, terrorist groups, 'mostly'), (Southampton University, terrorist groups, 'mostly')]
# ----------
# we are looking for terrorist groups, notably the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, notably, the, Taliban, ,, al Qeada, and, Southampton University]
# notably => [(Taliban, terrorist groups, 'notably'), (al Qeada, terrorist groups, 'notably'), (Southampton University, terrorist groups, 'notably')]
# ----------
# we are looking for terrorist groups, principally the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, principally, the, Taliban, ,, al Qeada, and, Southampton University]
# principally => [(Taliban, terrorist groups, 'principally'), (al Qeada, terrorist groups, 'principally'), (Southampton University, terrorist groups, 'principally')]
# ----------
# we are looking for terrorist groups, particularly the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, particularly, the, Taliban, ,, al Qeada, and, Southampton University]
# particularly => [(Taliban, terrorist groups, 'particularly'), (al Qeada, terrorist groups, 'particularly'), (Southampton University, terrorist groups, 'particularly')]
# ----------
# we are looking for terrorist groups, in particular the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, in, particular, the, Taliban, ,, al Qeada, and, Southampton University]
# in_particular => [(Taliban, terrorist groups, 'in_particular'), (al Qeada, terrorist groups, 'in_particular'), (Southampton University, terrorist groups, 'in_particular')]
# ----------
# we are looking for terrorist groups, except the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, except, the, Taliban, ,, al Qeada, and, Southampton University]
# except => [(Taliban, terrorist groups, 'except'), (al Qeada, terrorist groups, 'except'), (Southampton University, terrorist groups, 'except')]
# ----------
# we are looking for terrorist groups, other than the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, other, than, the, Taliban, ,, al Qeada, and, Southampton University]
# other_than => [(Taliban, terrorist groups, 'other_than'), (al Qeada, terrorist groups, 'other_than'), (Southampton University, terrorist groups, 'other_than')]
# ----------
# we are looking for terrorist groups, which are similar to the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, which, are, similar, to, the, Taliban, ,, al Qeada, and, Southampton University]
# which_be_similar_to => [(Taliban, terrorist groups, 'which_be_similar_to'), (al Qeada, terrorist groups, 'which_be_similar_to'), (Southampton University, terrorist groups, 'which_be_similar_to')]
# ----------
# we are looking for terrorist groups, examples of this being the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, examples, of, this, being, the, Taliban, ,, al Qeada, and, Southampton University]
# example_of_this_be => [(Taliban, terrorist groups, 'example_of_this_be'), (al Qeada, terrorist groups, 'example_of_this_be'), (Southampton University, terrorist groups, 'example_of_this_be')]
# ----------
# we are looking for terrorist groups types the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, types, the, Taliban, ,, al Qeada, and, Southampton University]
# type => [(Taliban, terrorist groups, ',type'), (al Qeada, terrorist groups, ',type'), (Southampton University, terrorist groups, ',type')]
# ----------
# we are looking for terrorist groups, whether the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, whether, the, Taliban, ,, al Qeada, and, Southampton University]
# whether => [(Taliban, terrorist groups, 'whether'), (al Qeada, terrorist groups, 'whether'), (Southampton University, terrorist groups, 'whether')]
# ----------
# we are looking for terrorist groups, compared to the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, compared, to, the, Taliban, ,, al Qeada, and, Southampton University]
# compare_to => [(Taliban, terrorist groups, 'compare_to'), (al Qeada, terrorist groups, 'compare_to'), (Southampton University, terrorist groups, 'compare_to')]
# ----------
# we are looking for terrorist groups, which may include the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, which, may, include, the, Taliban, ,, al Qeada, and, Southampton University]
# which may include => [(Taliban, terrorist groups, 'which_may_include'), (al Qeada, terrorist groups, 'which_may_include'), (Southampton University, terrorist groups, 'which_may_include')]
# ----------
# we are looking for such terrorist groups as the Taliban, al Qeada and Southampton University
# [we, are, looking, for, such terrorist groups, as, the, Taliban, ,, al Qeada, and, Southampton University]
# such_NOUN_as => []
# ----------
# we are looking for terrorist groups, the Taliban, al Qeada and Southampton University for instance
# [we, are, looking, for, terrorist groups, ,, the, Taliban, ,, al Qeada, and, Southampton University, for, instance]
# for_instance => []
# ----------
# examples of terrorist groups are the Taliban, al Qeada and Southampton University
# [examples of terrorist groups, are, the, Taliban, ,, al Qeada, and, Southampton University]
# example of => []
# ----------
# we are looking for terrorist groups, for example, the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, for, example, ,, the, Taliban, ,, al Qeada, and, Southampton University]
# for_example => [(Taliban, terrorist groups, 'for_example'), (al Qeada, terrorist groups, 'for_example'), (Southampton University, terrorist groups, 'for_example')]
# ----------
# we are looking for terrorist groups, e.g. the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, e.g., the Taliban, ,, al Qeada, and, Southampton University]
# e.g. => [(the Taliban, terrorist groups, 'eg'), (al Qeada, terrorist groups, 'eg'), (Southampton University, terrorist groups, 'eg')]
# ----------
# we are looking for terrorist groups, i.e. the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, i.e., the Taliban, ,, al Qeada, and, Southampton University]
# i.e. => [(the Taliban, terrorist groups, 'ie'), (al Qeada, terrorist groups, 'ie'), (Southampton University, terrorist groups, 'ie')]
# ----------
# we are looking for terrorist groups, among them, the Taliban, al Qeada and Southampton University
# [we, are, looking, for, terrorist groups, ,, among, them, ,, the, Taliban, ,, al Qeada, and, Southampton University]
# among_-PRON- => []
# ----------
# 4 / 26

# %%
# %%time
dirpath = r"C:\Users\Steve\OneDrive - University of Southampton\CNDPipeline\dataset\Leo Tolstoy"
file = "warandpeace_testdata.json"

with open(os.path.join(dirpath, file), "r") as f:
    docs = json.load(f)

hs = hpspacy.HearstPatterns(cnd.nlp, extended = True)
for doc in docs:
    hyponyms = hs.find_hyponyms(doc[2])
    #if len(hyponyms[1:]) != 3:
    print(doc[2])
    print([t for t in cnd(doc[2])])
    print(doc[1])
    print(doc[0], '=>', hyponyms)
    print('----------')
# Out:
# The younger ones occupied themselves as before, some playing cards (there was plenty of money, though there was no food), some with more innocent games, such as quoits and skittles
# [The, younger ones, occupied, themselves, as, before, ,, some, playing, cards, (, there, was, plenty of money, ,, though, there, was, no, food, ), ,, some, with, more, innocent games, ,, such, as, quoits, and, skittles]
# True
# such_as => [(quoits, innocent games, 'such_as'), (skittles, innocent games, 'such_as')]
# ----------
# The trench itself was the room, in which the lucky ones, such as the squadron commander, had a board, lying on piles at the end opposite the entrance, to serve as a table.
# [The, trench, itself, was, the, room, ,, in, which, the, lucky ones, ,, such, as, the, squadron commander, ,, had, a, board, ,, lying, on, piles, at, the, end opposite the entrance, ,, to, serve, as, a, table, .]
# True
# such_as => [(squadron commander, lucky ones, 'such_as')]
# ----------
# Through the hard century-old bark, even where there were no twigs, leaves had sprouted such as one could hardly believe the old veteran could have produced.
# True
# except => [(Prince Vasíli, reception room, 'except'), (eldest princess, reception room, 'except')]
# ----------
# He made use of every kind of mental device, except analogy, and passed too boldly, it seemed to Prince Andrew, from one to another.
# [He, made, use, of, every, kind of mental device, ,, except, analogy, ,, and, passed, too, boldly, ,, it, seemed, to, Prince Andrew, ,, from, one, to, another, .]
# True
# except => [(analogy, kind of mental device, 'except')]
# ----------
# There was really nothing to be seen in front except a barren descent hidden by dense mist.
# [There, was, really, nothing, to, be, seen, in, front, except, a, barren descent, hidden, by, dense mist, .]
# False
# except => [(barren descent, front, 'except')]
# ----------
# Kutúzov no one spoke of, except some who abused him in whispers, calling him a court weathercock and an old satyr.
# [Kutúzov, no, one, spoke, of, ,, except, some, who, abused, him, in, whispers, ,, calling, him, a, court, weathercock, and, an, old satyr, .]
# False
# except => []
# ----------
#
# []
# None
# other_than => []
# ----------
# In front was Glory, which was similar to those threads but rather thicker.
# [In, front, was, Glory, ,, which, was, similar, to, those, threads, but, rather, thicker, .]
# True
# which_be_similar_to => [(threads, Glory, 'which_be_similar_to')]
# ----------
#
# []
# None
# example_of_this_be => []
# ----------
# Countess Bezúkhova was present among other Russian ladies who had followed the sovereign from Petersburg to Vílna and eclipsed the refined Polish ladies by her massive, so-called Russian type of beauty
# [Countess Bezúkhova, was, present, among, other Russian ladies, who, had, followed, the, sovereign, from, Petersburg, to, Vílna, and, eclipsed, the, refined Polish ladies, by, her, massive, so-called Russian type of beauty]
# False
# type => []
# ----------
# When we do not at all understand the cause of an action, whether a crime, a good action, or even one that is simply nonmoral, we ascribe a greater amount of freedom to it.
# [When, we, do, not, at, all, understand, the, cause of an action, ,, whether, a, crime, ,, a, good action, ,, or, even, one, that, is, simply, nonmoral, ,, we, ascribe, a, greater amount of freedom, to, it, .]
# True
# whether => [(crime, cause of an action, 'whether'), (good action, cause of an action, 'whether'), (one, cause of an action, 'whether')]
# ----------
# She could not fathom whether it was curiosity, devotion, gratitude, or apprehension and distrust—but the expression on all the faces was identical.
# [She, could, not, fathom, whether, it, was, curiosity, ,, devotion, ,, gratitude, ,, or, apprehension, and, distrust, —, but, the, expression on all the faces, was, identical, .]
# False
# whether => []
# ----------
# He opened his eyes, hoping to see how the struggle of the Frenchmen with the gunners ended, whether the red-haired gunner had been killed or not and whether the cannon had been captured or saved.
# [He, opened, his, eyes, ,, hoping, to, see, how, the, struggle of the Frenchmen, with, the, gunners, ended, ,, whether, the, red-haired gunner, had, been, killed, or, not, and, whether, the, cannon, had, been, captured, or, saved, .]
# False
# weather => []
# ----------
#
# []
# None
# compare_to => []
# ----------
#
# []
# None
# which may include => []
# ----------
#
# []
# None
# for_instance => []
# ----------
# But the most amazing example of the ineffectiveness of the orders given by the authorities at that time was Napoleon’s attempt to stop the looting and re-establish discipline.
# [But, the, most, amazing example, of, the, ineffectiveness of the orders, given, by, the, authorities, at, that, time, was, Napoleon, ’s, attempt, to, stop, the, looting, and, re-establish discipline, .]
# False
# example_of => []
# ----------
# Of the two soups he chose turtle with savory patties and went on to the game without omitting a single dish or one of the wines.
# [Of, the, two, soups, he, chose, turtle with savory patties, and, went, on, to, the, game, without, omitting, a, single dish, or, one, of, the, wines, .]
# False
# one_of_the => []
# ----------
# She loved and knew Prince Andrew, he loved her only, and was to come one of these days and take her.
# [She, loved, and, knew, Prince Andrew, ,, he, loved, her, only, ,, and, was, to, come, one, of, these days, and, take, her, .]
# True
# one_of_these => []
# ----------
# Prince Andrew was one of those rare staff officers whose chief interest lay in the general progress of the war.
# [Prince Andrew, was, one, of, those, rare staff officers, whose, chief interest, lay, in, the, general progress of the war, .]
# True
# one_of_those => []
# ----------
#
# []
# None
# be_example_of => []
# ----------
#
# []
# None
# which_be_call => []
# ----------
#
# []
# None
# which_be_name => []
# ----------
#
# []
# None
# which_look_lile => []
# ----------
#
# []
# None
# which_sound_like => []
# ----------
# Casting a rapid glance at all those in the room and noticing the count’s confessor there, she glided up to him with a sort of amble, not exactly bowing yet seeming to grow suddenly smaller, and respectfully received the blessing first of one and then of another priest.
# [Casting, a, rapid glance, at, all, those, in, the, room, and, noticing, the, count’s confessor, there, ,, she, glided, up, to, him, with, a, sort, of, amble, ,, not, exactly, bowing, yet, seeming, to, grow, suddenly, smaller, ,, and, respectfully, received, the, blessing, first, of, one, and, then, of, another, priest, .]
# False
# sort_of => []
# ----------
# He felt it awkward to attract everyone’s attention and to be considered a lucky man and, with his plain face, to be looked on as a sort of Paris possessed of a Helen.
# [He, felt, it, awkward, to, attract, everyone’s attention, and, to, be, considered, a, lucky, man, and, ,, with, his, plain face, ,, to, be, looked, on, as, a, sort of Paris, possessed, of, a, Helen, .]
# False
# sort_of => []
# ----------
# /'Yes, I feel a kind of oppression,/' she said in reply to the prince’s question as to how she felt.
# [/'Yes, ,, I, feel, a, kind of oppression,/, ', she, said, in, reply, to, the, prince’s question, as, to, how, she, felt, .]
# False
# a_kind_of => []
# ----------
# Yet in this very repugnance to all his circumstances Pierre found a kind of tantalizing satisfaction.
# [Yet, in, this, very repugnance, to, all, his, circumstances, Pierre, found, a, kind of tantalizing satisfaction, .]
# False
# a_kind_of => []
# ----------
# Life was cheaper because it was circumscribed: that most expensive luxury, the kind of life that can be changed at any moment, was no longer his nor did he wish for it.
# [Life, was, cheaper, because, it, was, circumscribed, :, that, most, expensive luxury, ,, the, kind of life, that, can, be, changed, at, any, moment, ,, was, no, longer, his, nor, did, he, wish, for, it, .]
# False
# kind_of => []
# ----------
# Secondly, it is assumed that the goal toward which humanity is being led is known to the historians: to one of them this goal is the greatness of the Roman, Spanish, or French realm; to another it is liberty, equality, and a certain kind of civilization of a small corner of the world called Europe.
# [Secondly, ,, it, is, assumed, that, the, goal, toward, which, humanity, is, being, led, is, known, to, the, historians, :, to, one, of, them, this, goal, is, the, greatness of the Roman, Spanish, or French realm, ;, to, another, it, is, liberty, ,, equality, ,, and, a, certain kind, of, civilization, of, a, small corner of the world, called, Europe, .]
# False
# kind_of => []
# ----------
#
# []
# None
# form_of => []
# ----------
#
# []
# None
# as => []
# ----------
# Wall time: 2.47 s
