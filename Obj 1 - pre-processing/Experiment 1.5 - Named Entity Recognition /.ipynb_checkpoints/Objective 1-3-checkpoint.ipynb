# %%
# %%time
import pandas as pd
import spacy
nlp = spacy.load("en_core_web_md")
nlp.add_pipe("merge_entities")
# Out:
# /Users/stephenanningcorp/.local/lib/python3.8/site-packages/spacy/util.py:865: UserWarning: [W095] Model 'en_core_web_md' (3.1.0) was trained with spaCy v3.1 and may not be 100% compatible with the current version (3.4.1). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# CPU times: user 890 ms, sys: 130 ms, total: 1.02 s
# Wall time: 1.08 s
# <function spacy.pipeline.functions.merge_entities(doc: spacy.tokens.doc.Doc)>

# %%
import pandas as pd
from spacy.attrs import ORTH, POS, DEP, LEMMA, ENT_TYPE
from spacy.symbols import NOUN, PROPN, PRON, VERB

def display_simple(doc):
    
    return pd.DataFrame({
        'tokens': [token for token in doc],
        'Part of Speech tag': [f"{token.pos_} ({spacy.explain(token.pos_)})" for token in doc],
        'Dependency tag': [f"{token.dep_}, ({spacy.explain(token.dep_)})" for token in doc],
        'Lemma': [token.lemma_ for token in doc]
    })
    
def display_complex(doc):
    
    np_array = doc.to_array([ORTH, POS, DEP, LEMMA, ENT_TYPE])

    columns = ['Token', 'Part of Speech', 'Dependency', 'Lemma', 'Entity Type']
    df = pd.DataFrame(np_array, columns = columns)

    for col in df.columns:

        if col in ['Part of Speech', 'Dependency']:
            df[col] = df[col].apply(lambda token: f"{nlp.vocab.strings[token]} ({spacy.explain(nlp.vocab.strings[token])})")

        else:
            df[col] = df[col].apply(lambda token: f"{nlp.vocab.strings[token]}")
            
    return df

def get_semantic_units(doc):
    
    semantic_units = [NOUN, PROPN, PRON, VERB]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/1f/_bmdf7fs74g5yl2_4y7kq6_m0000gq/T/ipykernel_39545/2888238489.py in <module>
#       1 import pandas as pd
# ----> 2 from spacy.attrs import ORTH, POS, DEP, LEMMA, ENT_TYPE, NOUN, VERB, PROPN
#       3
#       4 def display_simple(doc):
#       5
#
# ImportError: cannot import name 'NOUN' from 'spacy.attrs' (/Users/stephenanningcorp/.local/lib/python3.8/site-packages/spacy/attrs.cpython-38-darwin.so)

# %%
texts = [
    """The evidence we have gathered all points to a collection of loosely affiliated terrorist organizations known as al Qaeda.""",
    """This group and its leader -- a person named Usama bin Laden -- are linked to many other organizations in different countries, including the Egyptian Islamic Jihad and the Islamic Movement of Uzbekistan"""
]

for text in texts:

    display(display_simple(nlp(text)))
# Out:
#            tokens   Part of Speech tag  \
# 0             The     DET (determiner)
# 1        evidence          NOUN (noun)
# 2              we       PRON (pronoun)
# 3            have      AUX (auxiliary)
# 4        gathered          VERB (verb)
# 5             all     DET (determiner)
# 6          points          NOUN (noun)
# 7              to     ADP (adposition)
# 8               a     DET (determiner)
# 9      collection          NOUN (noun)
# 10             of     ADP (adposition)
# 11        loosely         ADV (adverb)
# 12     affiliated          VERB (verb)
# 13      terrorist      ADJ (adjective)
# 14  organizations          NOUN (noun)
# 15          known          VERB (verb)
# 16             as     ADP (adposition)
# 17             al  PROPN (proper noun)
# 18          Qaeda  PROPN (proper noun)
# 19              .  PUNCT (punctuation)
#
#                                        Dependency tag         Lemma
# 0                                   det, (determiner)           the
# 1                                        ROOT, (root)      evidence
# 2                            nsubj, (nominal subject)            we
# 3                                    aux, (auxiliary)          have
# 4                   relcl, (relative clause modifier)        gather
# 5                                   det, (determiner)           all
# 6                               dobj, (direct object)         point
# 7                      prep, (prepositional modifier)            to
# 8                                   det, (determiner)             a
# 9                       pobj, (object of preposition)    collection
# 10                     prep, (prepositional modifier)            of
# 11                       advmod, (adverbial modifier)       loosely
# 12                        amod, (adjectival modifier)     affiliate
# 13                        amod, (adjectival modifier)     terrorist
# 14                      pobj, (object of preposition)  organization
# 15  acl, (clausal modifier of noun (adjectival cla...          know
# 16                     prep, (prepositional modifier)            as
# 17                               compound, (compound)            al
# 18                      pobj, (object of preposition)         Qaeda
# 19                               punct, (punctuation)             .
#            tokens                Part of Speech tag  \
# 0            This                  DET (determiner)
# 1           group                       NOUN (noun)
# 2             and  CCONJ (coordinating conjunction)
# 3             its                    PRON (pronoun)
# 4          leader                       NOUN (noun)
# 5              --               PUNCT (punctuation)
# 6               a                  DET (determiner)
# 7          person                       NOUN (noun)
# 8           named                       VERB (verb)
# 9           Usama               PROPN (proper noun)
# 10            bin               PROPN (proper noun)
# 11          Laden               PROPN (proper noun)
# 12             --               PUNCT (punctuation)
# 13            are                   AUX (auxiliary)
# 14         linked                       VERB (verb)
# 15             to                  ADP (adposition)
# 16           many                   ADJ (adjective)
# 17          other                   ADJ (adjective)
# 18  organizations                       NOUN (noun)
# 19             in                  ADP (adposition)
# 20      different                   ADJ (adjective)
# 21      countries                       NOUN (noun)
# 22              ,               PUNCT (punctuation)
# 23      including                       VERB (verb)
# 24            the                  DET (determiner)
# 25       Egyptian                   ADJ (adjective)
# 26        Islamic               PROPN (proper noun)
# 27          Jihad               PROPN (proper noun)
# 28            and  CCONJ (coordinating conjunction)
# 29            the                  DET (determiner)
# 30        Islamic               PROPN (proper noun)
# 31       Movement               PROPN (proper noun)
# 32             of                  ADP (adposition)
# 33     Uzbekistan               PROPN (proper noun)
#
#                                        Dependency tag         Lemma
# 0                                   det, (determiner)          this
# 1              nsubjpass, (nominal subject (passive))         group
# 2                      cc, (coordinating conjunction)           and
# 3                         poss, (possession modifier)           its
# 4                                    conj, (conjunct)        leader
# 5                                punct, (punctuation)            --
# 6                                   det, (determiner)             a
# 7                      appos, (appositional modifier)        person
# 8   acl, (clausal modifier of noun (adjectival cla...          name
# 9                                compound, (compound)         Usama
# 10                               compound, (compound)           bin
# 11                           oprd, (object predicate)         Laden
# 12                               punct, (punctuation)            --
# 13                     auxpass, (auxiliary (passive))            be
# 14                                       ROOT, (root)          link
# 15                     prep, (prepositional modifier)            to
# 16                        amod, (adjectival modifier)          many
# 17                        amod, (adjectival modifier)         other
# 18                      pobj, (object of preposition)  organization
# 19                     prep, (prepositional modifier)            in
# 20                        amod, (adjectival modifier)     different
# 21                      pobj, (object of preposition)       country
# 22                               punct, (punctuation)             ,
# 23                     prep, (prepositional modifier)       include
# 24                                  det, (determiner)           the
# 25                        amod, (adjectival modifier)      egyptian
# 26                               compound, (compound)       Islamic
# 27                      pobj, (object of preposition)         Jihad
# 28                     cc, (coordinating conjunction)           and
# 29                                  det, (determiner)           the
# 30                               compound, (compound)       Islamic
# 31                                   conj, (conjunct)      Movement
# 32                     prep, (prepositional modifier)            of
# 33                      pobj, (object of preposition)    Uzbekistan

# %%
from IPython.core.display import display, HTML

def display_side_by_side(dfs:list, captions:list, last = False):
    
    """Display tables side by side to save vertical space
    Input:
        dfs: list of pandas.DataFrame
        captions: list of table captions
    """
    
    output = ""

    heading_properties = [('font-size', '18px')]

    cell_properties = [('font-size', '16px')]

    dfstyle = [dict(selector="th", props=heading_properties),
               dict(selector="td", props=cell_properties)]
    
    combined = dict(zip(captions, dfs))
    
    for caption, df in combined.items():

        if last == False:
            output += df.style.set_table_attributes("style='display:inline'").\
                set_caption(caption).\
                _repr_html_()
            output += "\xa0\xa0\xa0"

        if last == True:
            output += df.style.set_table_attributes("style='display:inline'"). \
                set_caption(caption).\
                applymap('font-weight: bold', subset=pd.IndexSlice[len(df), :]).\
                _repr_html_()
            output += "\xa0\xa0\xa0"
            
    display(HTML(output))

# %%
from spacy.symbols import NOUN, PROPN, PRON, VERB

semantic_units = [NOUN, PROPN, PRON, VERB]


index = ["Semantic Unit", "word"]

df = lambda doc: pd.DataFrame([[spacy.explain(token.pos_).title(), token] for token in doc if token.pos in semantic_units], columns = index)

dfs = []

for text in texts:
    dfs.append(df(nlp(text)))

captions = ["Sentence 1", "Sentence 2"]
display_side_by_side(dfs, captions = captions)
# Out:
# <style type="text/css">
# </style>
# <table id="T_bd82f_" style='display:inline'>
#   <caption>Sentence 1</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Semantic Unit</th>
#       <th class="col_heading level0 col1" >word</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd82f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd82f_row0_col0" class="data row0 col0" >Noun</td>
#       <td id="T_bd82f_row0_col1" class="data row0 col1" >evidence</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd82f_row1_col0" class="data row1 col0" >Pronoun</td>
#       <td id="T_bd82f_row1_col1" class="data row1 col1" >we</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd82f_row2_col0" class="data row2 col0" >Verb</td>
#       <td id="T_bd82f_row2_col1" class="data row2 col1" >gathered</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd82f_row3_col0" class="data row3 col0" >Noun</td>
#       <td id="T_bd82f_row3_col1" class="data row3 col1" >points</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd82f_row4_col0" class="data row4 col0" >Noun</td>
#       <td id="T_bd82f_row4_col1" class="data row4 col1" >collection</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd82f_row5_col0" class="data row5 col0" >Verb</td>
#       <td id="T_bd82f_row5_col1" class="data row5 col1" >affiliated</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd82f_row6_col0" class="data row6 col0" >Noun</td>
#       <td id="T_bd82f_row6_col1" class="data row6 col1" >organizations</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bd82f_row7_col0" class="data row7 col0" >Verb</td>
#       <td id="T_bd82f_row7_col1" class="data row7 col1" >known</td>
#     </tr>
#     <tr>
#       <th id="T_bd82f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bd82f_row8_col0" class="data row8 col0" >Proper Noun</td>
#       <td id="T_bd82f_row8_col1" class="data row8 col1" >al Qaeda</td>
#     </tr>
#   </tbody>
# </table>
#    <style type="text/css">
# </style>
# <table id="T_7ba3d_" style='display:inline'>
#   <caption>Sentence 2</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Semantic Unit</th>
#       <th class="col_heading level0 col1" >word</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ba3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ba3d_row0_col0" class="data row0 col0" >Noun</td>
#       <td id="T_7ba3d_row0_col1" class="data row0 col1" >group</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ba3d_row1_col0" class="data row1 col0" >Pronoun</td>
#       <td id="T_7ba3d_row1_col1" class="data row1 col1" >its</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ba3d_row2_col0" class="data row2 col0" >Noun</td>
#       <td id="T_7ba3d_row2_col1" class="data row2 col1" >leader</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ba3d_row3_col0" class="data row3 col0" >Noun</td>
#       <td id="T_7ba3d_row3_col1" class="data row3 col1" >person</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ba3d_row4_col0" class="data row4 col0" >Verb</td>
#       <td id="T_7ba3d_row4_col1" class="data row4 col1" >named</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ba3d_row5_col0" class="data row5 col0" >Proper Noun</td>
#       <td id="T_7ba3d_row5_col1" class="data row5 col1" >Usama bin Laden</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ba3d_row6_col0" class="data row6 col0" >Verb</td>
#       <td id="T_7ba3d_row6_col1" class="data row6 col1" >linked</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ba3d_row7_col0" class="data row7 col0" >Noun</td>
#       <td id="T_7ba3d_row7_col1" class="data row7 col1" >organizations</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ba3d_row8_col0" class="data row8 col0" >Noun</td>
#       <td id="T_7ba3d_row8_col1" class="data row8 col1" >countries</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ba3d_row9_col0" class="data row9 col0" >Verb</td>
#       <td id="T_7ba3d_row9_col1" class="data row9 col1" >including</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7ba3d_row10_col0" class="data row10 col0" >Proper Noun</td>
#       <td id="T_7ba3d_row10_col1" class="data row10 col1" >the Egyptian Islamic Jihad</td>
#     </tr>
#     <tr>
#       <th id="T_7ba3d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7ba3d_row11_col0" class="data row11 col0" >Proper Noun</td>
#       <td id="T_7ba3d_row11_col1" class="data row11 col1" >the Islamic Movement of Uzbekistan</td>
#     </tr>
#   </tbody>
# </table>

# %%
import sys
sys.path.append('/Users/stephenanningcorp/Library/CloudStorage/OneDrive-UniversityofSouthampton/Hostile-Narrative-Analysis/cndlib')

# %%
print(sys.path)
# Out:
# ['/Users/stephenanningcorp/Library/CloudStorage/OneDrive-UniversityofSouthampton/Hostile-Narrative-Analysis/Obj 0 - pre-processing/Experiment 0.1 - Testing Named Entity Recognition in the spaCy models', '/Users/stephenanningcorp/opt/anaconda3/envs/spaCy_v3/lib/python38.zip', '/Users/stephenanningcorp/opt/anaconda3/envs/spaCy_v3/lib/python3.8', '/Users/stephenanningcorp/opt/anaconda3/envs/spaCy_v3/lib/python3.8/lib-dynload', '', '/Users/stephenanningcorp/.local/lib/python3.8/site-packages', '/Users/stephenanningcorp/opt/anaconda3/envs/spaCy_v3/lib/python3.8/site-packages', '/Users/stephenanningcorp/opt/anaconda3/envs/spaCy_v3/lib/python3.8/site-packages/IPython/extensions', '/Users/stephenanningcorp/.ipython', '/Users/stephenanningcorp/Library/CloudStorage/OneDrive-UniversityofSouthampton/Hostile-Narrative-Analysis/cndlib']
