# %%
import gensim
import datetime

print('creating word2vec model from GoogleNews-vectors-negative300.bin.gz')

text = 'C:/Users/Steve/Documents/Cultural Violence/GoogleNews-vectors-negative300.bin.gz'
#text = ''

model = gensim.models.KeyedVectors.load_word2vec_format(text, binary=True)

vocab = model.vocab.keys()
print(f"{len(vocab):,d}")
print(f'completed at {str(datetime.datetime.now())}')

# %%
# %%time

import datetime
import os

def get_dataset_dirpath(cwd):
    
    one_up = os.path.dirname(cwd)
    
    return os.path.join(one_up, 'dataset')

dataset_dirpath = get_dataset_dirpath(os.getcwd())

binladenpath = os.path.join(dataset_dirpath, 'Osama bin Laden/')
bushpath = os.path.join(dataset_dirpath, 'George Bush/')


Bush_FileList = [
    '20010914-Remarks at the National Day of Prayer & Remembrance Service.txt',
    '20010915-First Radio Address following 911.txt',
    '20010917-Address at Islamic Center of Washington, D.C..txt',
    '20010920-Address to Joint Session of Congress Following 911 Attacks.txt',
    '20010911-911 Address to the Nation.txt',
    '20011007-Operation Enduring Freedom in Afghanistan Address to the Nation.txt',
    '20011011-911 Pentagon Remembrance Address.txt',
    '20011011-Prime Time News Conference on War on Terror.txt',
    '20011026-Address on Signing the USA Patriot Act of 2001.txt',
    '20011110-First Address to the United Nations General Assembly.txt',
    '20011211-Address to Citadel Cadets.txt',
    '20011211-The World Will Always Remember 911.txt',
    '20020129-First (Official) Presidential State of the Union Address.txt'
]

binLaden_FileList = [
    '19960823-Declaration of Jihad Against the Americans Occupying the Land of the Two Holiest Sites.txt',
    '20010107-Osama Bin Laden Letter Calling For Global Islamic State.txt',
#     '20011109-Bin Laden\'s Statement The Sword Fell.txt',
    '20021124-OBL Letter to America.txt',
    '20041101-Al Jazeera Speech.txt'
           ]

records = {
    "bush": {"filepath": bushpath, "texts": Bush_FileList},
    "binladen": {"filepath": binladenpath, "texts": binLaden_FileList}
}

for orator, record in records.items():

    raw = ""
    for text in record["texts"]:
        with open(os.path.join(record["filepath"], text), 'r') as text:
            raw = raw + text.read()
                         
    record['fulltext'] = raw
    print(f'{orator} doc length = {len(raw)}')
    
    fulltext_path = os.path.join(record["filepath"], 'fulltext.txt')
        
    with open(fulltext_path, 'w') as text:
            text.write(raw)

print(f'completed at: {datetime.datetime.now().strftime("%b %d %Y %H:%M:%S")}')
# Out:
# bush doc length = 111934
# binladen doc length = 86384
# completed at: Oct 09 2022 07:26:12
# CPU times: user 2.39 ms, sys: 3.62 ms, total: 6.02 ms
# Wall time: 8.03 ms

# %%
# Applying pipeline

import spacy


print('setting up pipeline')
nlp = spacy.load('en_core_web_md')
print('applying pipeline')

bush_text = records['bush']['fulltext']

doc = nlp(bush_text)

print(f"document length: {len(doc)}")
print(f"number of entities: {len(doc.ents)}")

entset = set()

for ent in doc.ents:
    if ent.label_ in {'ORG', 'GPE', 'NORP'}:
        entset.add(ent.text.replace(' ', '_'))
    
print(f"number of entities: {len(entset)}")

print(f'completed at {str(datetime.datetime.now())}')
# Out:
# setting up pipeline
# applying pipeline
# document length: 22591
# number of entities: 995
# number of entities: 155
# completed at 2022-10-09 07:26:42.191008

# %%
### the purpose of this cell is to test the different ways to find similarity

import pandas as pd

array = {'Enemy', 'Friend', 'Terrorist', 'al_Qaida'}

word1 = input('Target Word 1: ')
word2 = input('Opposing Word 2: ')

print()
print(f"{word1}-{word2}") # showing words most similar to the target word, minus the opposing word
print(pd.DataFrame(model.most_similar(positive=[word1]), columns = [f"Closest to {word1} |", 'Similarity |']).T)
print('-----')
print('Similarity')
print(f"{word1}-{word2} similarity = {model.similarity(word1, word2)}") #showing the similarity of each word
# Out:
# Target Word 1:  Enemy
# Opposing Word 2:  Friend
# Enemy-Friend
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1f/_bmdf7fs74g5yl2_4y7kq6_m0000gq/T/ipykernel_65491/1465862583.py in <module>
#      10 print()
#      11 print(f"{word1}-{word2}") # showing words most similar to the target word, minus the opposing word
# ---> 12 print(pd.DataFrame(model.most_similar(positive=[word1]), columns = [f"Closest to {word1} |", 'Similarity |']).T)
#      13 print('-----')
#      14 print('Similarity')
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
### the purpose of this cell is to find the closest entity to a word

entity_scores = []
target_word = input('target word:')

#terrorism, islam, taliban, al_Qaeda, afghans, Usama_bin_Laden, terrorist, somalia, islamic jihad, iraq

#gypsy,

for ent in entset:
    try: 
        entity_scores.append([ent, model.similarity(target_word, ent)]) #showing the entities most closely associated with the target word
    except:
        pass

df2 = pd.DataFrame(entity_scores).sort_values(by=[1], ascending=False)
print(df2[0:31])

## rank all entities of the text relative to the in-group and out-group to each seed words, at least 5 seed words per group
## sum up scores of each entity to each word and divide by number of seed words
## create a method to measure closeness to seed word and distance from its opposite
## output: 2 scores: average distance to ingroup and average to outgroup chose lowest score to infer group membership

## for entities e
##    average = 0
##    for seed words w
##       average = average + distance(e,w)
##       divide by number of seed words
## average = average/seed words
## e.outgroupscore = average
## if 

##{entity1: {'ingroup': {'friend': 0.5, 'ally': 0.4}, 'outgroup': {'enemy': 0.1, 'adversary': 0.15}}}

# %%
### the purpose of this cell is to determine whether entities are ingroup or outgroup

entity_dict = {}

#ingroup_nouns = model.most_similar('friend')
#outgroup_nouns = model.most_similar('enemy')

## note, Google News model does not have all words in lower case and noun phrases are connected with underscore
## note, model also does not convert words to lower case

outgroup_nouns = {'Enemies', 'Enemy', 'Terrorists', 'Terrorist', 'Nazi', 'Nazis', 'enemies', 'enemy', 'terrorists', 'terrorist', 'nazi', 'nazis'} # ingroup and outgroup words taken from commonly used words in speeches
ingroup_nouns = {'Friend', 'Friends', 'Sons', 'Daughters', 'Brethren', 'Hero', 'Heroes', 'friend', 'friends', 'sons', 'daughters', 'brethren', 'hero', 'heroes'} 

for ent in new_doc.ents: # entity extraction completed by Spacy pipeline
    if ent.label_ in {'ORG', 'GPE', 'NORP'}: #creates a set of entity types: organisation (ORG), geopolitical (GPE) or nationality or religious or political group (NORP)
        entset.add(ent.text.replace(' ', '_')) # noun phrases in model are created using _

entity_dict = {}

for i, ent in enumerate(entset):
    ingroup_list = []
    outgroup_list = []
    ingp_score = 0
    outgp_score = 0
       
    for ingp, outgp in zip(ingroup_nouns, outgroup_nouns): # this needs changing since the lists are of different length
        try:
            ingp_sim =  model.similarity(ent, ingp) # score for most similar word to ingroup entity
            outgp_sim = model.similarity(ent, outgp) # score for most similar word to outgroup entity

            ingroup_list.append((ingp, ingp_sim )) # create a list of words most similar to ingroup entity
            outgroup_list.append((outgp, outgp_sim)) # create a list of word most similar to outgroup entity

            ingp_score += ingp_sim # create total score for words most similar to ingroup words
            outgp_score += outgp_sim # create total score for words most similary to outgroup words
            
            entity_dict[ent] = { # create a dict object for each entity
                              'ingroup': sorted(ingroup_list, key=lambda tup:(-tup[1], tup[0])), # add list of ingroup words similar to entity and sort
                              'outgroup' : sorted(outgroup_list, key=lambda tup:(-tup[1], tup[0])), # add list of outgroup words similar to entity and sort
                              'ingroup_score': ingp_score/len(ingroup_nouns), # average score for ingroup association
                              'outgroup_score': outgp_score/len(outgroup_nouns) # average score for outgroup association
                             }
        except:
            pass
       

    
for ent, key in sorted(zip(entity_dict, entity_dict.values())):
    if key['ingroup_score'] < key['outgroup_score']: # if average outgroup score is higher, the entity is more likely to be outgroup
        print(f"{ent} is outgroup:")
        print(f"ingroup score = {key['ingroup_score']}, outgroup score = {key['outgroup_score']}")
        print(f"distance between ingroup average and outgroup average: {key['outgroup_score'] - key['ingroup_score']}")
    else:
        print(f"{ent} is ingroup:") # else the entity is more likely to be ingroup
        print(f"ingroup score = {key['ingroup_score']}, outgroup score = {key['outgroup_score']}")
        print(f"distance between ingroup average and outgroup average: {key['ingroup_score'] - key['outgroup_score']}")
    print()          
    
    print("outgroup words: ", end = "")
    for word in key['outgroup'][0:3]:
              print(word, end = ' | ')
    print()
    
    print("ingroup word: ", end = "")          
    for word in key['ingroup'][0:3]:
              print(word, end = ' | ')
    print()
    print('-----')

# %%
for i, ent in enumerate(entset):
    print(f"{i}/{len(entset)}")
    try:
        print(f"{ent}:")
        for word in model.wv.most_similar(ent):
            print(word, end = ' | ')
    except:
        print(f"{ent}: not in vocabulary")
    print('-----')

# %%
### The purpose of this cell is to identify the ingroup and outgroups recursively

import itertools as it
import statistics

ent_set = set()

# organisation (ORG), geopolitical (GPE) or nationality or religious or political group (NORP)

for ent in new_doc.ents: # entity extraction completed by Spacy pipeline 
    if ent.label_ in {'ORG', 'GPE', 'NORP'} and ent.text in model: #creates a set of entity types and checks if in model: 
        ent_set.add(ent.text.replace(' ', '_')) # noun phrases in model are created using _
       

seed_dict = {'IN' : ['friend', 'Friend'],
             'OUT' : ['enemy', 'Enemy']}

#data initialisation complete

##recursive categoriser

def grp_categoriser(ent_set, seed_dict):

    def ent_scores(ent_set, seed_dict): #function to score each entity of ent_set relative to ingroup/outgroup similarity
        entity_dict = {}
        n = 0
        for i, entity in enumerate(ent_set):
            ingrp_scores = {}
            outgrp_scores = {}
            ingrp_ave = 0
            outgrp_ave = 0
            
            try:
                #create dict of ingroup scores for each seed word
                ingrp_scores = {'seed words' : seed_dict['IN'], 'ingrp_scores' : [model.similarity(entity, ingp) for ingp in seed_dict['IN']]} 
                
                #create dict of outgroup scores for each seed word
                outgrp_scores = {'seed words' : seed_dict['OUT'], 'outgrp_scores' : [model.similarity(entity, ingp) for ingp in seed_dict['OUT']]} 

                # calculate averge score signifying closeness to ingroup
                ingrp_ave = sum(ingrp_scores['ingrp_scores']) / float(len(ingrp_scores['ingrp_scores'])) 
                
                # calculate averge score signifying closeness to outgroup
                outgrp_ave = sum(outgrp_scores['outgrp_scores']) / float(len(outgrp_scores['outgrp_scores'])) 

                
                if entity == 'America':
                    print(f'InGroup average: {ingrp_ave}')
                    print(pd.DataFrame.from_dict(ingrp_scores).T)
                    print('-----')
                    print(f'OutGroup average: {outgrp_ave}')
                    print(pd.DataFrame.from_dict(outgrp_scores).T)
                    print('-------------')
                
                if ingrp_ave > outgrp_ave: # if the ingrp_ave is higher that outgrp entity is in the ingroup
                    entity_dict[i] = {'entity' : entity,
                                        'group' : 'IN',
                                        'score' : ingrp_ave}
                else:
                    entity_dict[i] = {'entity' : entity, # ...otherwise entity is in the outgroup
                                        'group' : 'OUT',
                                        'score' : outgrp_ave}
            except:
                print('passing: ', n)
                n+= 1
                pass

        return entity_dict.pop(max(entity_dict.items(), key=lambda score: score[1]['score'])[0]) #return max entry from entity dictionary

    def group_append(max_key, ent_set, seed_dict):
        if len(ent_set) == 1:
            return seed_dict

        else:  
            
            ent_set.remove(max_key['entity']) # remove max entity from entity set
            
            seed_dict[max_key['group']].append(max_key['entity']) # add max entity to appropriate seed word grouping
            
            return group_append(ent_scores(ent_set, seed_dict), ent_set, seed_dict) # re-evaluate based on new seed words
        
    return group_append(ent_scores(ent_set, seed_dict), ent_set, seed_dict)


print('Total ', len(ent_set), 'entities')
groupings = (grp_categoriser(ent_set, seed_dict))
print('InGroup', len(groupings['IN']), 'entities')
print(sorted(groupings['IN']))
print('----')
print('OutGroup', len(groupings['OUT']), 'entities')
print(sorted(groupings['OUT']))
# Out:
# Total  96 entities
# C:\Users\Steve\Anaconda3\lib\site-packages\gensim\matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int32 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16214321553707123
#                       0         1
# seed words        enemy     Enemy
# outgrp_scores  0.174609  0.149677
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.14297782878081003
#                       0         1         2
# seed words        enemy     Enemy   Taliban
# outgrp_scores  0.174609  0.149677  0.104647
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1353284865617752
#                       0         1         2        3
# seed words        enemy     Enemy   Taliban   Afghan
# outgrp_scores  0.174609  0.149677  0.104647  0.11238
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15280336141586304
#                       0         1         2        3            4
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15401280423005423
#                       0         1         2        3            4        5
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1521009568657194
#                       0         1         2        3            4        5  \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                      6
# seed words       Kabul
# outgrp_scores  0.14063
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.14512222819030285
#                       0         1         2        3            4        5  \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                      6          7
# seed words       Kabul       NATO
# outgrp_scores  0.14063  0.0962711
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15784376031822628
#                       0         1         2        3            4        5  \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                      6          7         8
# seed words       Kabul       NATO  Pakistan
# outgrp_scores  0.14063  0.0962711  0.259616
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15452781617641448
#                       0         1         2        3            4        5  \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                      6          7         8          9
# seed words       Kabul       NATO  Pakistan  Pakistani
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1562293524091894
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15524446964263916
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.14981687527436477
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12
# seed words         Iraqi
# outgrp_scores  0.0846857
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15733260554926737
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13
# seed words         Iraqi      Iraq
# outgrp_scores  0.0846857  0.255037
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15883972644805908
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14
# seed words         Iraqi      Iraq      Iran
# outgrp_scores  0.0846857  0.255037  0.179939
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15645595081150532
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14        15
# seed words         Iraqi      Iraq      Iran   Iranian
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15414185690529206
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14        15        16
# seed words         Iraqi      Iraq      Iran   Iranian     Hamas
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699  0.117116
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15093307031525505
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14        15        16         17
# seed words         Iraqi      Iraq      Iran   Iranian     Hamas  Hezbollah
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699  0.117116  0.0963837
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1539307142558851
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14        15        16         17  \
# seed words         Iraqi      Iraq      Iran   Iranian     Hamas  Hezbollah
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699  0.117116  0.0963837
#
#                      18
# seed words     Israelis
# outgrp_scores  0.207888
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16037196815013885
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9           10         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  Pakistanis  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684    0.173245   0.144411
#
#                       12        13        14        15        16         17  \
# seed words         Iraqi      Iraq      Iran   Iranian     Hamas  Hezbollah
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699  0.117116  0.0963837
#
#                      18        19
# seed words     Israelis    Israel
# outgrp_scores  0.207888  0.282756
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16485869316827684
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         11  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Musharraf
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...   0.144411
#
#                       12        13        14        15        16         17  \
# seed words         Iraqi      Iraq      Iran   Iranian     Hamas  Hezbollah
# outgrp_scores  0.0846857  0.255037  0.179939  0.120699  0.117116  0.0963837
#
#                      18        19        20
# seed words     Israelis    Israel      Arab
# outgrp_scores  0.207888  0.282756  0.254593
#
# [2 rows x 21 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16301998834718356
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         12  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Iraqi
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.0846857
#
#                      13        14        15        16         17        18  \
# seed words         Iraq      Iran   Iranian     Hamas  Hezbollah  Israelis
# outgrp_scores  0.255037  0.179939  0.120699  0.117116  0.0963837  0.207888
#
#                      19        20        21
# seed words       Israel      Arab   Somalia
# outgrp_scores  0.282756  0.254593  0.124407
#
# [2 rows x 22 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.15825318253558615
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        13  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Iraq
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.255037
#
#                      14        15        16         17        18        19  \
# seed words         Iran   Iranian     Hamas  Hezbollah  Israelis    Israel
# outgrp_scores  0.179939  0.120699  0.117116  0.0963837  0.207888  0.282756
#
#                      20        21         22
# seed words         Arab   Somalia     Kosovo
# outgrp_scores  0.254593  0.124407  0.0533835
#
# [2 rows x 23 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16034223387638727
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        14  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Iran
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.179939
#
#                      15        16         17        18        19        20  \
# seed words      Iranian     Hamas  Hezbollah  Israelis    Israel      Arab
# outgrp_scores  0.120699  0.117116  0.0963837  0.207888  0.282756  0.254593
#
#                      21         22       23
# seed words      Somalia     Kosovo    Egypt
# outgrp_scores  0.124407  0.0533835  0.20839
#
# [2 rows x 24 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1641574275493622
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        15  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...   Iranian
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.120699
#
#                      16         17        18        19        20        21  \
# seed words        Hamas  Hezbollah  Israelis    Israel      Arab   Somalia
# outgrp_scores  0.117116  0.0963837  0.207888  0.282756  0.254593  0.124407
#
#                       22       23         24
# seed words        Kosovo    Egypt  Palestine
# outgrp_scores  0.0533835  0.20839   0.255722
#
# [2 rows x 25 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16344660864426538
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        16  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...     Hamas
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.117116
#
#                       17        18        19        20        21         22  \
# seed words     Hezbollah  Israelis    Israel      Arab   Somalia     Kosovo
# outgrp_scores  0.0963837  0.207888  0.282756  0.254593  0.124407  0.0533835
#
#                     23         24        25
# seed words       Egypt  Palestine    Muslim
# outgrp_scores  0.20839   0.255722  0.145676
#
# [2 rows x 26 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16262226744934363
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         17  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Hezbollah
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.0963837
#
#                      18        19        20        21         22       23  \
# seed words     Israelis    Israel      Arab   Somalia     Kosovo    Egypt
# outgrp_scores  0.207888  0.282756  0.254593  0.124407  0.0533835  0.20839
#
#                       24        25        26
# seed words     Palestine    Muslim   Muslims
# outgrp_scores   0.255722  0.145676  0.141189
#
# [2 rows x 27 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1643014975956508
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        18  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Israelis
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.207888
#
#                      19        20        21         22       23         24  \
# seed words       Israel      Arab   Somalia     Kosovo    Egypt  Palestine
# outgrp_scores  0.282756  0.254593  0.124407  0.0533835  0.20839   0.255722
#
#                      25        26        27
# seed words       Muslim   Muslims     Islam
# outgrp_scores  0.145676  0.141189  0.209641
#
# [2 rows x 28 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16371353073366757
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        19  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Israel
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.282756
#
#                      20        21         22       23         24        25  \
# seed words         Arab   Somalia     Kosovo    Egypt  Palestine    Muslim
# outgrp_scores  0.254593  0.124407  0.0533835  0.20839   0.255722  0.145676
#
#                      26        27       28
# seed words      Muslims     Islam  Islamic
# outgrp_scores  0.141189  0.209641  0.14725
#
# [2 rows x 29 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16544467707475027
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        20  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Arab
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.254593
#
#                      21         22       23         24        25        26  \
# seed words      Somalia     Kosovo    Egypt  Palestine    Muslim   Muslims
# outgrp_scores  0.124407  0.0533835  0.20839   0.255722  0.145676  0.141189
#
#                      27       28        29
# seed words        Islam  Islamic      Jews
# outgrp_scores  0.209641  0.14725  0.215648
#
# [2 rows x 30 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1647531707440653
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        21  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...   Somalia
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.124407
#
#                       22       23         24        25        26        27  \
# seed words        Kosovo    Egypt  Palestine    Muslim   Muslims     Islam
# outgrp_scores  0.0533835  0.20839   0.255722  0.145676  0.141189  0.209641
#
#                     28        29          30
# seed words     Islamic      Jews  Christians
# outgrp_scores  0.14725  0.215648    0.144008
#
# [2 rows x 31 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16497418796643615
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         22  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...     Kosovo
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.0533835
#
#                     23         24        25        26        27       28  \
# seed words       Egypt  Palestine    Muslim   Muslims     Islam  Islamic
# outgrp_scores  0.20839   0.255722  0.145676  0.141189  0.209641  0.14725
#
#                      29          30        31
# seed words         Jews  Christians    Jewish
# outgrp_scores  0.215648    0.144008  0.171826
#
# [2 rows x 32 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1619635917472117
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...       23  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Egypt
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.20839
#
#                       24        25        26        27       28        29  \
# seed words     Palestine    Muslim   Muslims     Islam  Islamic      Jews
# outgrp_scores   0.255722  0.145676  0.141189  0.209641  0.14725  0.215648
#
#                        30        31         32
# seed words     Christians    Jewish      Cairo
# outgrp_scores    0.144008  0.171826  0.0656245
#
# [2 rows x 33 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16537719943067608
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         24  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Palestine
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...   0.255722
#
#                      25        26        27       28        29          30  \
# seed words       Muslim   Muslims     Islam  Islamic      Jews  Christians
# outgrp_scores  0.145676  0.141189  0.209641  0.14725  0.215648    0.144008
#
#                      31         32        33
# seed words       Jewish      Cairo    Russia
# outgrp_scores  0.171826  0.0656245  0.278026
#
# [2 rows x 34 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16070030970232826
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        25  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Muslim
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.145676
#
#                      26        27       28        29          30        31  \
# seed words      Muslims     Islam  Islamic      Jews  Christians    Jewish
# outgrp_scores  0.141189  0.209641  0.14725  0.215648    0.144008  0.171826
#
#                       32        33          34
# seed words         Cairo    Russia     Bosnian
# outgrp_scores  0.0656245  0.278026  0.00168606
#
# [2 rows x 35 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1623587351706293
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        26  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...   Muslims
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.141189
#
#                      27       28        29          30        31         32  \
# seed words        Islam  Islamic      Jews  Christians    Jewish      Cairo
# outgrp_scores  0.209641  0.14725  0.215648    0.144008  0.171826  0.0656245
#
#                      33          34        35
# seed words       Russia     Bosnian    Soviet
# outgrp_scores  0.278026  0.00168606  0.220404
#
# [2 rows x 36 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16076525844432213
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        27  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...     Islam
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.209641
#
#                     28        29          30        31         32        33  \
# seed words     Islamic      Jews  Christians    Jewish      Cairo    Russia
# outgrp_scores  0.14725  0.215648    0.144008  0.171826  0.0656245  0.278026
#
#                        34        35      36
# seed words        Bosnian    Soviet    U.N.
# outgrp_scores  0.00168606  0.220404  0.1034
#
# [2 rows x 37 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16048150195887215
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...       28  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Islamic
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.14725
#
#                      29          30        31         32        33  \
# seed words         Jews  Christians    Jewish      Cairo    Russia
# outgrp_scores  0.215648    0.144008  0.171826  0.0656245  0.278026
#
#                        34        35      36        37
# seed words        Bosnian    Soviet    U.N.       CIA
# outgrp_scores  0.00168606  0.220404  0.1034  0.149983
#
# [2 rows x 38 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1600360495921893
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        29  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Jews
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.215648
#
#                        30        31         32        33          34  \
# seed words     Christians    Jewish      Cairo    Russia     Bosnian
# outgrp_scores    0.144008  0.171826  0.0656245  0.278026  0.00168606
#
#                      35      36        37        38
# seed words       Soviet    U.N.       CIA  Pentagon
# outgrp_scores  0.220404  0.1034  0.149983  0.143109
#
# [2 rows x 39 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.16713356152176856
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...          30  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Christians
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...    0.144008
#
#                      31         32        33          34        35      36  \
# seed words       Jewish      Cairo    Russia     Bosnian    Soviet    U.N.
# outgrp_scores  0.171826  0.0656245  0.278026  0.00168606  0.220404  0.1034
#
#                      37        38        39
# seed words          CIA  Pentagon      U.S.
# outgrp_scores  0.149983  0.143109  0.443937
#
# [2 rows x 40 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.17169334612241605
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        31  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Jewish
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.171826
#
#                       32        33          34        35      36        37  \
# seed words         Cairo    Russia     Bosnian    Soviet    U.N.       CIA
# outgrp_scores  0.0656245  0.278026  0.00168606  0.220404  0.1034  0.149983
#
#                      38        39        40
# seed words     Pentagon      U.S.     India
# outgrp_scores  0.143109  0.443937  0.354085
#
# [2 rows x 41 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1773259604261035
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         32  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      Cairo
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.0656245
#
#                      33          34        35      36        37        38  \
# seed words       Russia     Bosnian    Soviet    U.N.       CIA  Pentagon
# outgrp_scores  0.278026  0.00168606  0.220404  0.1034  0.149983  0.143109
#
#                      39        40         41
# seed words         U.S.     India  Americans
# outgrp_scores  0.443937  0.354085   0.408263
#
# [2 rows x 42 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1807845047740049
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        33  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Russia
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.278026
#
#                        34        35      36        37        38        39  \
# seed words        Bosnian    Soviet    U.N.       CIA  Pentagon      U.S.
# outgrp_scores  0.00168606  0.220404  0.1034  0.149983  0.143109  0.443937
#
#                      40         41        42
# seed words        India  Americans     China
# outgrp_scores  0.354085   0.408263  0.326043
#
# [2 rows x 43 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.18194155869158832
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...          34  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...     Bosnian
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.00168606
#
#                      35      36        37        38        39        40  \
# seed words       Soviet    U.N.       CIA  Pentagon      U.S.     India
# outgrp_scores  0.220404  0.1034  0.149983  0.143109  0.443937  0.354085
#
#                       41        42        43
# seed words     Americans     China   British
# outgrp_scores   0.408263  0.326043  0.231695
#
# [2 rows x 44 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.19149038990338643
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        35      36  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    Soviet    U.N.
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.220404  0.1034
#
#                      37        38        39        40         41        42  \
# seed words          CIA  Pentagon      U.S.     India  Americans     China
# outgrp_scores  0.149983  0.143109  0.443937  0.354085   0.408263  0.326043
#
#                      43        44
# seed words      British  American
# outgrp_scores  0.231695  0.611639
#
# [2 rows x 45 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.19456731301286947
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...      36        37  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...    U.N.       CIA
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.1034  0.149983
#
#                      38        39        40         41        42        43  \
# seed words     Pentagon      U.S.     India  Americans     China   British
# outgrp_scores  0.143109  0.443937  0.354085   0.408263  0.326043  0.231695
#
#                      44        45
# seed words     American   Germany
# outgrp_scores  0.611639  0.333029
#
# [2 rows x 46 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.19424796104431152
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        37  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...       CIA
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.149983
#
#                      38        39        40         41        42        43  \
# seed words     Pentagon      U.S.     India  Americans     China   British
# outgrp_scores  0.143109  0.443937  0.354085   0.408263  0.326043  0.231695
#
#                      44        45        46
# seed words     American   Germany    Nazism
# outgrp_scores  0.611639  0.333029  0.179558
#
# [2 rows x 47 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1935343878964583
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        38  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Pentagon
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.143109
#
#                      39        40         41        42        43        44  \
# seed words         U.S.     India  Americans     China   British  American
# outgrp_scores  0.443937  0.354085   0.408263  0.326043  0.231695  0.611639
#
#                      45        46        47
# seed words      Germany    Nazism      Nazi
# outgrp_scores  0.333029  0.179558  0.159996
#
# [2 rows x 48 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.19757070225112291
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        39  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...      U.S.
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.443937
#
#                      40         41        42        43        44        45  \
# seed words        India  Americans     China   British  American   Germany
# outgrp_scores  0.354085   0.408263  0.326043  0.231695  0.611639  0.333029
#
#                      46        47        48
# seed words       Nazism      Nazi     Japan
# outgrp_scores  0.179558  0.159996  0.391314
#
# [2 rows x 49 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.19900955021381378
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...        40  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...     India
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...  0.354085
#
#                       41        42        43        44        45        46  \
# seed words     Americans     China   British  American   Germany    Nazism
# outgrp_scores   0.408263  0.326043  0.231695  0.611639  0.333029  0.179558
#
#                      47        48        49
# seed words         Nazi     Japan    France
# outgrp_scores  0.159996  0.391314  0.269513
#
# [2 rows x 50 columns]
# -------------
# InGroup average: 0.03736474830657244
#                       0          1
# seed words       friend     Friend
# ingrp_scores -0.0187747  0.0935042
# -----
# OutGroup average: 0.1984493913603764
#                      0         1         2        3            4        5   \
# seed words        enemy     Enemy   Taliban   Afghan  Afghanistan  Afghans
# outgrp_scores  0.174609  0.149677  0.104647  0.11238     0.222703  0.16006
#
#                     6          7         8          9   ...         41  \
# seed words       Kabul       NATO  Pakistan  Pakistani  ...  Americans
# outgrp_scores  0.14063  0.0962711  0.259616   0.124684  ...   0.408263
#
#                      42        43        44        45        46        47  \
# seed words        China   British  American   Germany    Nazism      Nazi
# outgrp_scores  0.326043  0.231695  0.611639  0.333029  0.179558  0.159996
#
#                      48        49        50
# seed words        Japan    France     Kenya
# outgrp_scores  0.391314  0.269513  0.170441
#
# [2 rows x 51 columns]
# -------------
# InGroup 13 entities
# ['Adjutant', 'AmeriCorps', 'Cabinet', 'Citadel', 'Friend', 'Guadalcanal', 'House', 'Marine', 'Navy', 'State', 'Treasury', 'Union', 'friend']
# ----
# OutGroup 86 entities
# ['ATF', 'Afghan', 'Afghanistan', 'Afghans', 'America', 'American', 'Americans', 'Annapolis', 'Arab', 'Arlington', 'Army', 'Australia', 'Berlin', 'Bosnian', 'British', 'CIA', 'Cairo', 'California', 'Canada', 'China', 'Christian', 'Christians', 'Congress', 'Crawford', 'Dallas', 'Democrats', 'Eastern', 'Egypt', 'Enemy', 'FBI', 'France', 'Gambia', 'Georgia', 'Germany', 'Hamas', 'Hezbollah', 'India', 'Iran', 'Iranian', 'Iraq', 'Iraqi', 'Islam', 'Islamic', 'Israel', 'Israelis', 'Japan', 'Jewish', 'Jews', 'Jordan', 'Kabul', 'Kenya', 'Kosovo', 'Mecca', 'Medicare', 'Mexico', 'Musharraf', 'Muslim', 'Muslims', 'NATO', 'Nazi', 'Nazism', 'Normandy', 'Pakistan', 'Pakistani', 'Pakistanis', 'Palestine', 'Paris', 'Pennsylvania', 'Pentagon', 'Philippines', 'Republicans', 'Russia', 'Senate', 'Sensenbrenner', 'Seoul', 'Somalia', 'Soviet', 'Taliban', 'Tanzania', 'Tokyo', 'U.N.', 'U.S.', 'Virginia', 'Washington', 'enemy', 'mafia']
