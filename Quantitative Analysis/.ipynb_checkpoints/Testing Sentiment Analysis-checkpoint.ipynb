# %% [markdown]
# # Testing Sentiment Analysis
# -----
#
# In this notebook we test sentiment analysis techniques for analysing natural language for which there are three experiments.
#
# In the first experiment we compare different document scores for each text.
#
# In the second experiment we compare scores for named entities identified in each document.
#
# The sentiment analysis APIs we test are general purpose provided by Text Blob and state-of-the-art provided by both IBM's Watson and Google.

# %% [markdown]
# ## Instantiate the Pipeline

# %%
# %%time
import importlib
import pipeline
importlib.reload(pipeline)

cnd = pipeline.CND()

print([name for name in cnd.nlp.pipe_names])
# Out:
# ['tagger', 'parser', 'ner', 'Named Entity Matcher', 'merge_entities', 'Concept Matcher']
# Wall time: 24.6 s

# %% [markdown]
# ## Instantiate the Dataset

# %%
# %%time
import importlib
from IPython.display import clear_output
import cndobjects
importlib.reload(cndobjects)


dirpath = r'C:\\Users\\Steve\\OneDrive - University of Southampton\\CNDPipeline\\dataset'

orators = cndobjects.Dataset(cnd, dirpath)
clear_output(wait=True)

display(orators.summarise())
# Out:
#                         Name Text Count Word Count
# Ref
# hitler 0        Adolf Hitler          1    706,100
# bush   1         George Bush         14    143,936
# king   2  Martin Luther King          5    122,815
# laden  3     Osama bin Laden          6     93,646
# Totals 4                             26  1,066,497
# Wall time: 1min

# %% [markdown]
# ## Experiment 1 - Document Sentiment Scores
#
# In this first experiment we analysis the overall document sentiment scores.

# %% [markdown]
# ### Test 1 - Overall Document Scores
#
# In this first test we look at how each API scores each text of the dataset overall.

# %% [markdown]
# #### - Get Watson API Results and Store on File
#
# Get the data from the online API and store on file to save from repeated calls.
#
# API Documentation
# - https://cloud.ibm.com/apidocs/natural-language-understanding
#
# Source Code
# - http://watson-developer-cloud.github.io/python-sdk/v1.0.2/_modules/watson_developer_cloud/natural_language_understanding_v1.html

# %%
# %%time

import json
import jsonlines
import os
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import Features, ConceptsOptions, EmotionOptions, EntitiesOptions, KeywordsOptions, CategoriesOptions, SentimentOptions

# apikey = XXXX
# url = XXXX

# authenticator = IAMAuthenticator(apikey)
# service = NaturalLanguageUnderstandingV1(version='2019-07-12', authenticator=authenticator)
# service.set_service_url(url)

# filepath = os.getcwd()

# watson_results = list()
    
# for text in orators.texts:
#     watson_results.append({
#         "ref" : text.ref,
#         "title" : text.title,
#         "targets" : list(set([str(ent) for ent in text.doc.ents if ent.label_ in ["GPE", "NORP", "ORG", "PERSON"]])),
#         "result" : service.analyze(
#                     text=str(text.doc.text),
#                     features=Features(
#                         concepts=ConceptsOptions(limit=50),
#                         emotion=EmotionOptions(targets = targets),
#                         entities=EntitiesOptions(emotion=True, sentiment=True),
#                         keywords=KeywordsOptions(emotion=True, sentiment=True),
#                         categories=CategoriesOptions(),
#                         sentiment=SentimentOptions()
#                     )).get_result()
#     })
    
# jsonl_filename = "watsonresults.jsonl"
# with jsonlines.open(os.path.join(filepath, jsonl_filename), 'w') as writer:
#     writer.write_all(watson_results)
# Out:
# Wall time: 0 ns

# %% [markdown]
# #### - Get Google API Results and store on file
#
# Authentication
# - https://cloud.google.com/docs/authentication/getting-started
#
# Dashboard
# - https://console.cloud.google.com/home/dashboard?project=modern-heading-262419

# %%
# Imports the Google Cloud client library
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types

# Instantiates a client
client = language.LanguageServiceClient()

# The text to analyze
text = u'Hello, world!'
document = types.Document(
    content=text,
    type=enums.Document.Type.PLAIN_TEXT)

# Detects the sentiment of the text
sentiment = client.analyze_sentiment(document=document).document_sentiment

print(f'Text: {text}')
print(f'Sentiment: {sentiment.score}, {sentiment.magnitude}')
# Out:
# Text: Hello, world!
# Sentiment: 0.6000000238418579, 0.6000000238418579

# %%
import pandas as pd
from textblob import TextBlob
# display(pd.DataFrame(orators["bush"].framework()))

def sentiment_summary(dataset):

    """
    create a summary array of the Text() objects in Orator()
    """
    
    attrs = ["ref", "datestamp", "title", "word count", "TextBlob"]
    
    df = []
    for text in dataset:
        df.append([str(getattr(text, attr)) for attr in attrs[:3]])
        df[-1].append(len(text)) # get word count
        df[-1].append(TextBlob(str(text)).sentiment[0])

    df = pd.DataFrame(df, columns = attrs)
    
    return df

df = sentiment_summary(orators.texts)
df["Watson"] = [obj["result"]["sentiment"]["document"]["score"] for obj in watson_results]
display(df.style.background_gradient(cmap="Blues", subset = df.columns[-2:]))
# Out:
# <style  type="text/css" >
#     #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow0_col4 {
#             background-color:  #58a1cf;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow0_col5 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow1_col4 {
#             background-color:  #5ba3d0;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow1_col5 {
#             background-color:  #08488e;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow2_col4 {
#             background-color:  #2272b6;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow2_col5 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow3_col4 {
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow3_col5 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow4_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow4_col5 {
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow5_col4 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow5_col5 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow6_col4 {
#             background-color:  #1967ad;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow6_col5 {
#             background-color:  #105ba4;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow7_col4 {
#             background-color:  #82bbdb;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow7_col5 {
#             background-color:  #d7e6f5;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow8_col4 {
#             background-color:  #2777b8;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow8_col5 {
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow9_col4 {
#             background-color:  #4090c5;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow9_col5 {
#             background-color:  #2171b5;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow10_col4 {
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow10_col5 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow11_col4 {
#             background-color:  #549fcd;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow11_col5 {
#             background-color:  #edf4fc;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow12_col4 {
#             background-color:  #1c6ab0;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow12_col5 {
#             background-color:  #1966ad;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow13_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow13_col5 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow14_col4 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow14_col5 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow15_col4 {
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow15_col5 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow16_col4 {
#             background-color:  #2b7bba;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow16_col5 {
#             background-color:  #1561a9;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow17_col4 {
#             background-color:  #7db8da;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow17_col5 {
#             background-color:  #d3e4f3;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow18_col4 {
#             background-color:  #66abd4;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow18_col5 {
#             background-color:  #dfebf7;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow19_col4 {
#             background-color:  #5aa2cf;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow19_col5 {
#             background-color:  #e3eef8;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow20_col4 {
#             background-color:  #4997c9;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow20_col5 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow21_col4 {
#             background-color:  #3484bf;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow21_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow22_col4 {
#             background-color:  #6fb0d7;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow22_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow23_col4 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow23_col5 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow24_col4 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow24_col5 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow25_col4 {
#             background-color:  #3585bf;
#             color:  #000000;
#         }    #T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow25_col5 {
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }</style><table id="T_b261ae82_bb96_11ea_9a27_5800e3d0fa4c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ref</th>        <th class="col_heading level0 col1" >datestamp</th>        <th class="col_heading level0 col2" >title</th>        <th class="col_heading level0 col3" >word count</th>        <th class="col_heading level0 col4" >TextBlob</th>        <th class="col_heading level0 col5" >Watson</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b261ae82_bb96_11ea_9a27_5800e3d0fa4clevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow0_col0" class="data row0 col0" >hitler</td>
#                         <td id="T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow0_col1" class="data row0 col1" >2020-06-30</td>
#                         <td id="T_b261ae82_bb96_11ea_9a27_5800e3d0fa4crow0_col2" class="data row0 col2" >Mein Kampf</td>
#                         <td id="T_b261ae82_

# %%
# %%time
# https://stackoverflow.com/questions/20618804/how-to-smooth-a-curve-in-the-right-way

import matplotlib
import matplotlib.pyplot as plt
from collections import OrderedDict
from textblob import TextBlob
import pandas as pd
import numpy as np
from scipy.signal import savgol_filter

def smoothing(sentiment_list, window_size):
    window_size = window_size
    numbers_series = pd.Series(sentiment_list)
    windows = numbers_series.rolling(window_size)
    moving_averages = windows.mean()

    moving_averages_list = moving_averages.tolist()
    
    return moving_averages_list[window_size - 1:]

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

def x_axis(sentiment_list):
    total_len = len(sentiment_list)
    return [(i / total_len)*100 for i in range(total_len)]

def textblob_sentiment(document):
    sentiment = list()
    max_values = list()
    min_values = list()
    max_value = ("", 0)
    min_value = ("", 0)
    
    for sentence in document.doc.sents:
        rawtext = sentence.text
        sentiment.extend([TextBlob(rawtext).sentiment[0]])
        if sentiment[-1] == 1:
            max_values.append((rawtext, sentiment[-1]))
        if sentiment[-1] == -1:
            min_values.append((rawtext, sentiment[-1]))
        if max(sentiment) < 1 and max(sentiment) > max_value[1]:
            max_value = (rawtext, sentiment[-1])
        if min(sentiment) > -1 and min(sentiment) < min_value[1]:
            min_value = (rawtext, sentiment[-1])
            
#     pd.set_option('display.max_columns', None)
#     display(pd.DataFrame(min_value))
        
    return sentiment

plt.rcParams['figure.figsize'] = [20, 10]
fig, ax = plt.subplots()
axes = plt.gca()
axes.set_ylim([-1,1])
ax.grid()


def add_plot(text, window, poly):
    #y_axis = savgol_filter(get_sentiment(text), window, poly)
    print(len(text) // 1000)
    y_axis = smoothing(textblob_sentiment(text), len(text)//1000)
    
    ax.plot(x_axis(y_axis), y_axis, label = text.title)
    
    
window = 100
poly = 1
text = orators["king"][1]
add_plot(text, 20, poly)
text = orators["hitler"][0]
add_plot(text, 100, poly)

ax.legend(prop={"size":15})
ax.set(xlabel='percentage through the document', ylabel='rolling average sentiment',
       title="Comparing Sentiment Analysis of Different Texts")

plt.show()
